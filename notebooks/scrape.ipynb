# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from time import sleep
import pandas as pd
import random
import json
import numpy as np
import io
import csv
import os
import datetime

# %%
exchange = {
    'NASDAQ': 'NasdaqGS',
    'New York Stock Exchange Inc.': 'NYSE'
}

# %%
# driver = webdriver.Chrome()
# search_url = 'https://workers.finchat.io/company/$$$-&&&/valuation'
# 
# df = pd.read_csv('../data/sp500-left.csv')
# 
# for index, row in df.iterrows():
#     url = search_url.replace('$$$', exchange[row['Exchange']]).replace('&&&', row['Ticker'])
#     print(url)
#     driver.get(url)
#     sleep(1)
#     print(driver.page_source)
#     break

# %%
exchanges = ['NasdaqGS', 'NYSE']
driver = webdriver.Chrome()
search_url = 'https://workers.finchat.io/company/$$$-&&&/valuation'

df = pd.read_csv('../data/sp500-left.csv', names=['ticker'])

for index, row in df.iterrows():
    for exchange in exchanges:
        url = search_url.replace('$$$', exchange).replace('&&&', row['ticker'])
        print(url)
        driver.get(url)
        sleep(random.randint(2,7))
        body = driver.find_element(By.XPATH, '//body/pre').get_attribute('innerHTML')
        if 'Not Found' not in body:
            f = open('../data/extra/' + row['ticker'] + '.json', 'w')
            f.write(body)
            break
        sleep(random.randint(1,3))
# Out:
# https://workers.finchat.io/company/NasdaqGS-UNM/valuation
# https://workers.finchat.io/company/NYSE-UNM/valuation
# https://workers.finchat.io/company/NasdaqGS-GGG/valuation
# https://workers.finchat.io/company/NYSE-GGG/valuation
# https://workers.finchat.io/company/NasdaqGS-AVY/valuation
# https://workers.finchat.io/company/NYSE-AVY/valuation
# https://workers.finchat.io/company/NasdaqGS-UTHR/valuation
# https://workers.finchat.io/company/NasdaqGS-KIM/valuation
# https://workers.finchat.io/company/NYSE-KIM/valuation
# https://workers.finchat.io/company/NasdaqGS-LBRDA/valuation
# https://workers.finchat.io/company/NYSE-LBRDA/valuation
# https://workers.finchat.io/company/NasdaqGS-XPO/valuation
# https://workers.finchat.io/company/NYSE-XPO/valuation
# https://workers.finchat.io/company/NasdaqGS-SNAP/valuation
# https://workers.finchat.io/company/NYSE-SNAP/valuation
# https://workers.finchat.io/company/NasdaqGS-WMG/valuation
# https://workers.finchat.io/company/NasdaqGS-JBHT/valuation
# https://workers.finchat.io/company/NasdaqGS-IEX/valuation
# https://workers.finchat.io/company/NYSE-IEX/valuation
# https://workers.finchat.io/company/NasdaqGS-WPC/valuation
# https://workers.finchat.io/company/NYSE-WPC/valuation
# https://workers.finchat.io/company/NasdaqGS-DKS/valuation
# https://workers.finchat.io/company/NYSE-DKS/valuation
# https://workers.finchat.io/company/NasdaqGS-BAH/valuation
# https://workers.finchat.io/company/NYSE-BAH/valuation
# https://workers.finchat.io/company/NasdaqGS-SGI/valuation
# https://workers.finchat.io/company/NYSE-SGI/valuation
# https://workers.finchat.io/company/NasdaqGS-SN/valuation
# https://workers.finchat.io/company/NYSE-SN/valuation
# https://workers.finchat.io/company/NasdaqGS-JKHY/valuation
# https://workers.finchat.io/company/NasdaqGS-PFGC/valuation
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 18
#      16     f.write(body)
#      17     break
# ---> 18 sleep(random.randint(1,3))
#
# KeyboardInterrupt:

# %%
exchanges = ['NasdaqGS', 'NYSE']
driver = webdriver.Chrome()
search_url = 'https://workers.finchat.io/company/$$$-&&&/market-data'

df = pd.read_csv('../data/sp500-left.csv', names=['ticker'])

for index, row in df.iterrows():
    for exchange in exchanges:
        url = search_url.replace('$$$', exchange).replace('&&&', row['ticker'])
        print(url)
        driver.get(url)
        sleep(random.randint(2,7))
        body = driver.find_element(By.XPATH, '//body/pre').get_attribute('innerHTML')
        if 'Not Found' not in body:
            f = open('../data/extra-data/market-data/' + row['ticker'] + '.json', 'w')
            f.write(body)
            break
        sleep(random.randint(1,3))
# Out:
# https://workers.finchat.io/company/NasdaqGS-UNM/market-data
# https://workers.finchat.io/company/NYSE-UNM/market-data
# https://workers.finchat.io/company/NasdaqGS-GGG/market-data
# https://workers.finchat.io/company/NYSE-GGG/market-data
# https://workers.finchat.io/company/NasdaqGS-AVY/market-data
# https://workers.finchat.io/company/NYSE-AVY/market-data
# https://workers.finchat.io/company/NasdaqGS-UTHR/market-data
# https://workers.finchat.io/company/NasdaqGS-KIM/market-data
# https://workers.finchat.io/company/NYSE-KIM/market-data
# https://workers.finchat.io/company/NasdaqGS-LBRDA/market-data
# https://workers.finchat.io/company/NYSE-LBRDA/market-data
# https://workers.finchat.io/company/NasdaqGS-XPO/market-data
# https://workers.finchat.io/company/NYSE-XPO/market-data
# https://workers.finchat.io/company/NasdaqGS-SNAP/market-data
# https://workers.finchat.io/company/NYSE-SNAP/market-data
# https://workers.finchat.io/company/NasdaqGS-WMG/market-data
# https://workers.finchat.io/company/NasdaqGS-JBHT/market-data
# https://workers.finchat.io/company/NasdaqGS-IEX/market-data
# https://workers.finchat.io/company/NYSE-IEX/market-data
# https://workers.finchat.io/company/NasdaqGS-WPC/market-data
# https://workers.finchat.io/company/NYSE-WPC/market-data
# https://workers.finchat.io/company/NasdaqGS-DKS/market-data
# https://workers.finchat.io/company/NYSE-DKS/market-data
# https://workers.finchat.io/company/NasdaqGS-BAH/market-data
# https://workers.finchat.io/company/NYSE-BAH/market-data
# https://workers.finchat.io/company/NasdaqGS-SGI/market-data
# https://workers.finchat.io/company/NYSE-SGI/market-data
# https://workers.finchat.io/company/NasdaqGS-SN/market-data
# https://workers.finchat.io/company/NYSE-SN/market-data
# https://workers.finchat.io/company/NasdaqGS-JKHY/market-data
# https://workers.finchat.io/company/NasdaqGS-PFGC/market-data
# https://workers.finchat.io/company/NYSE-PFGC/market-data
# https://workers.finchat.io/company/NasdaqGS-RGA/market-data
# https://workers.finchat.io/company/NYSE-RGA/market-data
# https://workers.finchat.io/company/NasdaqGS-TXT/market-data
# https://workers.finchat.io/company/NYSE-TXT/market-data
# https://workers.finchat.io/company/NasdaqGS-MAS/market-data
# https://workers.finchat.io/company/NYSE-MAS/market-data
# https://workers.finchat.io/company/NasdaqGS-REG/market-data
# https://workers.finchat.io/company/NasdaqGS-TKO/market-data
# https://workers.finchat.io/company/NYSE-TKO/market-data
# https://workers.finchat.io/company/NasdaqGS-MORN/market-data
# https://workers.finchat.io/company/NasdaqGS-FNMA/market-data
# https://workers.finchat.io/company/NYSE-FNMA/market-data
# https://workers.finchat.io/company/NasdaqGS-ACI/market-data
# https://workers.finchat.io/company/NYSE-ACI/market-data
# https://workers.finchat.io/company/NasdaqGS-ELS/market-data
# https://workers.finchat.io/company/NYSE-ELS/market-data
# https://workers.finchat.io/company/NasdaqGS-ILMN/market-data
# https://workers.finchat.io/company/NasdaqGS-CNA/market-data
# https://workers.finchat.io/company/NYSE-CNA/market-data
# https://workers.finchat.io/company/NasdaqGS-GLPI/market-data
# https://workers.finchat.io/company/NasdaqGS-APG/market-data
# https://workers.finchat.io/company/NYSE-APG/market-data
# https://workers.finchat.io/company/NasdaqGS-TXRH/market-data
# https://workers.finchat.io/company/NasdaqGS-WWD/market-data
# https://workers.finchat.io/company/NasdaqGS-EWBC/market-data
# https://workers.finchat.io/company/NasdaqGS-INCY/market-data
# https://workers.finchat.io/company/NasdaqGS-ALGN/market-data
# https://workers.finchat.io/company/NasdaqGS-TER/market-data
# https://workers.finchat.io/company/NasdaqGS-INSM/market-data
# https://workers.finchat.io/company/NasdaqGS-HIMS/market-data
# https://workers.finchat.io/company/NYSE-HIMS/market-data
# https://workers.finchat.io/company/NasdaqGS-AR/market-data
# https://workers.finchat.io/company/NYSE-AR/market-data
# https://workers.finchat.io/company/NasdaqGS-CART/market-data
# https://workers.finchat.io/company/NasdaqGS-SOLV/market-data
# https://workers.finchat.io/company/NYSE-SOLV/market-data
# https://workers.finchat.io/company/NasdaqGS-COHR/market-data
# https://workers.finchat.io/company/NYSE-COHR/market-data
# https://workers.finchat.io/company/NasdaqGS-H/market-data
# https://workers.finchat.io/company/NYSE-H/market-data
# https://workers.finchat.io/company/NasdaqGS-CLH/market-data
# https://workers.finchat.io/company/NYSE-CLH/market-data
# https://workers.finchat.io/company/NasdaqGS-HOLX/market-data
# https://workers.finchat.io/company/NasdaqGS-CPT/market-data
# https://workers.finchat.io/company/NYSE-CPT/market-data
# https://workers.finchat.io/company/NasdaqGS-HLI/market-data
# https://workers.finchat.io/company/NYSE-HLI/market-data
# https://workers.finchat.io/company/NasdaqGS-JNPR/market-data
# https://workers.finchat.io/company/NYSE-JNPR/market-data
# https://workers.finchat.io/company/NasdaqGS-MTZ/market-data
# https://workers.finchat.io/company/NYSE-MTZ/market-data
# https://workers.finchat.io/company/NasdaqGS-UHS/market-data
# https://workers.finchat.io/company/NYSE-UHS/market-data
# https://workers.finchat.io/company/NasdaqGS-SJM/market-data
# https://workers.finchat.io/company/NYSE-SJM/market-data
# https://workers.finchat.io/company/NasdaqGS-EHC/market-data
# https://workers.finchat.io/company/NYSE-EHC/market-data
# https://workers.finchat.io/company/NasdaqGS-BLDR/market-data
# https://workers.finchat.io/company/NYSE-BLDR/market-data
# https://workers.finchat.io/company/NasdaqGS-PRMB/market-data
# https://workers.finchat.io/company/NYSE-PRMB/market-data
# https://workers.finchat.io/company/NasdaqGS-NBIX/market-data
# https://workers.finchat.io/company/NasdaqGS-RGLD/market-data
# https://workers.finchat.io/company/NasdaqGS-LAMR/market-data
# https://workers.finchat.io/company/NasdaqGS-X/market-data
# https://workers.finchat.io/company/NYSE-X/market-data
# https://workers.finchat.io/company/NasdaqGS-PAA/market-data
# https://workers.finchat.io/company/NasdaqGS-PPC/market-data
# https://workers.finchat.io/company/NasdaqGS-FTAI/market-data
# https://workers.finchat.io/company/NasdaqGS-ARE/market-data
# https://workers.finchat.io/company/NYSE-ARE/market-data
# https://workers.finchat.io/company/NasdaqGS-RKLB/market-data
# https://workers.finchat.io/company/NYSE-RKLB/market-data
# https://workers.finchat.io/company/NasdaqGS-DOC/market-data
# https://workers.finchat.io/company/NYSE-DOC/market-data
# https://workers.finchat.io/company/NasdaqGS-ITT/market-data
# https://workers.finchat.io/company/NYSE-ITT/market-data
# https://workers.finchat.io/company/NasdaqGS-EXEL/market-data
# https://workers.finchat.io/company/NasdaqGS-CRS/market-data
# https://workers.finchat.io/company/NYSE-CRS/market-data
# https://workers.finchat.io/company/NasdaqGS-VNOM/market-data
# https://workers.finchat.io/company/NasdaqGS-BXP/market-data
# https://workers.finchat.io/company/NYSE-BXP/market-data
# https://workers.finchat.io/company/NasdaqGS-CIEN/market-data
# https://workers.finchat.io/company/NYSE-CIEN/market-data
# https://workers.finchat.io/company/NasdaqGS-OC/market-data
# https://workers.finchat.io/company/NYSE-OC/market-data
# https://workers.finchat.io/company/NasdaqGS-NLY/market-data
# https://workers.finchat.io/company/NYSE-NLY/market-data
# https://workers.finchat.io/company/NasdaqGS-CHRW/market-data
# https://workers.finchat.io/company/NasdaqGS-POOL/market-data
# https://workers.finchat.io/company/NasdaqGS-RBC/market-data
# https://workers.finchat.io/company/NYSE-RBC/market-data
# https://workers.finchat.io/company/NasdaqGS-LINE/market-data
# https://workers.finchat.io/company/NasdaqGS-IONQ/market-data
# https://workers.finchat.io/company/NYSE-IONQ/market-data
# https://workers.finchat.io/company/NasdaqGS-BEN/market-data
# https://workers.finchat.io/company/NYSE-BEN/market-data
# https://workers.finchat.io/company/NasdaqGS-CCK/market-data
# https://workers.finchat.io/company/NYSE-CCK/market-data
# https://workers.finchat.io/company/NasdaqGS-MANH/market-data
# https://workers.finchat.io/company/NasdaqGS-PSHZF/market-data
# https://workers.finchat.io/company/NYSE-PSHZF/market-data
# https://workers.finchat.io/company/NasdaqGS-BROS/market-data
# https://workers.finchat.io/company/NYSE-BROS/market-data
# https://workers.finchat.io/company/NasdaqGS-MOS/market-data
# https://workers.finchat.io/company/NYSE-MOS/market-data
# https://workers.finchat.io/company/NasdaqGS-TTAN/market-data
# https://workers.finchat.io/company/NasdaqGS-TLN/market-data
# https://workers.finchat.io/company/NasdaqGS-BMRN/market-data
# https://workers.finchat.io/company/NasdaqGS-NDSN/market-data
# https://workers.finchat.io/company/NasdaqGS-ENTG/market-data
# https://workers.finchat.io/company/NasdaqGS-TAP/market-data
# https://workers.finchat.io/company/NYSE-TAP/market-data
# https://workers.finchat.io/company/NasdaqGS-SCI/market-data
# https://workers.finchat.io/company/NYSE-SCI/market-data
# https://workers.finchat.io/company/NasdaqGS-DRS/market-data
# https://workers.finchat.io/company/NasdaqGS-BWXT/market-data
# https://workers.finchat.io/company/NYSE-BWXT/market-data
# https://workers.finchat.io/company/NasdaqGS-WTRG/market-data
# https://workers.finchat.io/company/NYSE-WTRG/market-data
# https://workers.finchat.io/company/NasdaqGS-PNW/market-data
# https://workers.finchat.io/company/NYSE-PNW/market-data
# https://workers.finchat.io/company/NasdaqGS-TEM/market-data
# https://workers.finchat.io/company/NasdaqGS-KNSL/market-data
# https://workers.finchat.io/company/NYSE-KNSL/market-data
# https://workers.finchat.io/company/NasdaqGS-AKAM/market-data
# https://workers.finchat.io/company/NasdaqGS-OHI/market-data
# https://workers.finchat.io/company/NYSE-OHI/market-data
# https://workers.finchat.io/company/NasdaqGS-PCTY/market-data
