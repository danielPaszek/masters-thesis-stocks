# %%
from headers import *
from sklearn.tree import DecisionTreeClassifier
import pandas as pd
import numpy as np
from utils.custom_train_test_split import *
import os
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from sklearn.svm import SVC, LinearSVC
from sklearn.metrics import classification_report, make_scorer, confusion_matrix
from sklearn.pipeline import Pipeline
import matplotlib.pyplot as plt
from joblib import dump, load
from IPython.display import Markdown, display
from math import sqrt
import json

# %%
cutoffs = [0.0, 0.01, 0.02, 0.03, 0.05, 0.07, 0.10, 0.15, 0.20, 0.25, 0.35]

trainDf, testDf = per_year_train_test_split(['../data/combined_inner_ticker.csv', '../data/extra-data/combined_inner_ticker.csv'])
X_train = trainDf[ratioKeys + relativeRatioKeys]
X_test = testDf[ratioKeys + relativeRatioKeys]

resultsToPlot = {}

for yLabel in yAlpha:
    if yLabel not in resultsToPlot:
        resultsToPlot[yLabel] = {}
    for cutoff in cutoffs:
        y_train = np.where(trainDf[yLabel] <= cutoff, 0, 1)
        y_test = np.where(testDf[yLabel] <= cutoff, 0, 1)
        pipelines = {
            'tree': Pipeline([
                ('scaler', StandardScaler()),
                ('tree', DecisionTreeClassifier())
            ]),
            'svc': Pipeline([
                ('scaler', StandardScaler()),
                ('svc', LinearSVC())
            ])
        }
        params = [
            {
                'tree__criterion': ["gini", "entropy", "log_loss"],
            },
            {
                'svc__C': [0.1, 0.5, 1.0, 5.0, 10.0],
                'svc__penalty': ['l1', 'l2']
            }
        ]
        for (key, pipeline), param_grid in zip(pipelines.items(), params):
            grid = GridSearchCV(pipeline,
                        param_grid,
                        cv=StratifiedKFold(3, shuffle=True, random_state=3),
                        verbose=1,
                        refit=True,
                        n_jobs=-1,
                        # scoring='f1',
                        )
            grid.fit(X_train, y_train)
            y_pred = grid.predict(X_test)
            wholeTestData = testDf.loc[testDf.index.intersection(X_test.index)]
            
            xTaken = X_test[y_pred == 1]
            xTrue = X_test[y_test == 1]
            
            takenData = testDf.loc[testDf.index.intersection(xTaken.index)]
            trueData = testDf.loc[testDf.index.intersection(xTrue.index)]
            
            prc = round(takenData.loc[:, yLabel].count() / wholeTestData.loc[:, yLabel].count(), 4) * 100
            print(f'MODEL {key}')
            print(f'For {yLabel}, yCutoff = {cutoff}, taken used - {takenData.loc[:, yLabel].count()} is {prc}%')
            print(f'Mean was {round(takenData.loc[:, yLabel].mean() * 100, 2)}%, median was {round(takenData.loc[:, yLabel].median()*100, 2)}%')
            print(f'% of True in dataset {round(len(y_test[y_test==1]) / len(y_test) * 100, 2)}% resulted in {round(trueData.loc[:, yLabel].mean() * 100, 2)}% and median {round(trueData.loc[:, yLabel].median() * 100,2)}%')
            print('-----------')
            
            if key not in resultsToPlot[yLabel]:
                resultsToPlot[yLabel][key] = []
            resultsToPlot[yLabel][key].append({
                'mean': takenData.loc[:, yLabel].mean(),
                'median': takenData.loc[:, yLabel].median(),
                'taken': takenData.loc[:, yLabel].count()
            })
# Out:
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For alpha1Year, yCutoff = 0.0, taken used - 6173 is 48.02%
# Mean was 3.32%, median was 0.29%
# % of True in dataset 49.72% resulted in 24.04% and median 16.89%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For alpha1Year, yCutoff = 0.0, taken used - 2171 is 16.89%
# Mean was 5.96%, median was 0.97%
# % of True in dataset 49.72% resulted in 24.04% and median 16.89%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For alpha1Year, yCutoff = 0.01, taken used - 6113 is 47.55%
# Mean was 4.12%, median was 0.76%
# % of True in dataset 48.22% resulted in 24.78% and median 17.55%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For alpha1Year, yCutoff = 0.01, taken used - 1017 is 7.91%
# Mean was 6.33%, median was 0.86%
# % of True in dataset 48.22% resulted in 24.78% and median 17.55%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For alpha1Year, yCutoff = 0.02, taken used - 5893 is 45.839999999999996%
# Mean was 4.59%, median was 1.46%
# % of True in dataset 46.6% resulted in 25.58% and median 18.38%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For alpha1Year, yCutoff = 0.02, taken used - 489 is 3.8%
# Mean was 3.72%, median was -1.27%
# % of True in dataset 46.6% resulted in 25.58% and median 18.38%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For alpha1Year, yCutoff = 0.03, taken used - 5580 is 43.41%
# Mean was 3.02%, median was 0.15%
# % of True in dataset 44.79% resulted in 26.52% and median 19.17%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For alpha1Year, yCutoff = 0.03, taken used - 239 is 1.8599999999999999%
# Mean was 3.9%, median was -1.89%
# % of True in dataset 44.79% resulted in 26.52% and median 19.17%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For alpha1Year, yCutoff = 0.05, taken used - 5455 is 42.43%
# Mean was 3.36%, median was 0.55%
# % of True in dataset 41.7% resulted in 28.18% and median 20.68%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For alpha1Year, yCutoff = 0.05, taken used - 77 is 0.6%
# Mean was 9.56%, median was 8.38%
# % of True in dataset 41.7% resulted in 28.18% and median 20.68%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For alpha1Year, yCutoff = 0.07, taken used - 5152 is 40.08%
# Mean was 4.75%, median was 1.4%
# % of True in dataset 38.58% resulted in 29.98% and median 22.52%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For alpha1Year, yCutoff = 0.07, taken used - 28 is 0.22%
# Mean was 11.81%, median was -7.06%
# % of True in dataset 38.58% resulted in 29.98% and median 22.52%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For alpha1Year, yCutoff = 0.1, taken used - 4298 is 33.43%
# Mean was 5.02%, median was 1.36%
# % of True in dataset 34.07% resulted in 32.82% and median 25.08%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For alpha1Year, yCutoff = 0.1, taken used - 6 is 0.05%
# Mean was -16.28%, median was -15.25%
# % of True in dataset 34.07% resulted in 32.82% and median 25.08%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For alpha1Year, yCutoff = 0.15, taken used - 3964 is 30.84%
# Mean was 3.18%, median was -0.6%
# % of True in dataset 27.02% resulted in 38.13% and median 29.62%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For alpha1Year, yCutoff = 0.15, taken used - 9 is 0.06999999999999999%
# Mean was -11.86%, median was -17.49%
# % of True in dataset 27.02% resulted in 38.13% and median 29.62%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For alpha1Year, yCutoff = 0.2, taken used - 3108 is 24.18%
# Mean was 5.94%, median was 1.69%
# % of True in dataset 21.48% resulted in 43.45% and median 34.29%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For alpha1Year, yCutoff = 0.2, taken used - 9 is 0.06999999999999999%
# Mean was 58.91%, median was 80.06%
# % of True in dataset 21.48% resulted in 43.45% and median 34.29%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For alpha1Year, yCutoff = 0.25, taken used - 2409 is 18.740000000000002%
# Mean was 5.73%, median was 0.83%
# % of True in dataset 17.13% resulted in 48.75% and median 38.75%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For alpha1Year, yCutoff = 0.25, taken used - 0 is 0.0%
# Mean was nan%, median was nan%
# % of True in dataset 17.13% resulted in 48.75% and median 38.75%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For alpha1Year, yCutoff = 0.35, taken used - 1485 is 11.55%
# Mean was 3.3%, median was -1.64%
# % of True in dataset 10.28% resulted in 61.56% and median 49.82%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For alpha1Year, yCutoff = 0.35, taken used - 0 is 0.0%
# Mean was nan%, median was nan%
# % of True in dataset 10.28% resulted in 61.56% and median 49.82%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For adjustedAlpha1Year, yCutoff = 0.0, taken used - 6441 is 50.11%
# Mean was 4.33%, median was 1.34%
# % of True in dataset 50.46% resulted in 24.3% and median 17.35%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For adjustedAlpha1Year, yCutoff = 0.0, taken used - 2095 is 16.3%
# Mean was 6.59%, median was 2.14%
# % of True in dataset 50.46% resulted in 24.3% and median 17.35%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For adjustedAlpha1Year, yCutoff = 0.01, taken used - 6437 is 50.07%
# Mean was 4.47%, median was 1.17%
# % of True in dataset 48.62% resulted in 25.2% and median 18.21%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For adjustedAlpha1Year, yCutoff = 0.01, taken used - 890 is 6.92%
# Mean was 10.12%, median was 4.05%
# % of True in dataset 48.62% resulted in 25.2% and median 18.21%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For adjustedAlpha1Year, yCutoff = 0.02, taken used - 5864 is 45.62%
# Mean was 4.9%, median was 1.19%
# % of True in dataset 47.05% resulted in 25.99% and median 18.87%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For adjustedAlpha1Year, yCutoff = 0.02, taken used - 394 is 3.06%
# Mean was 5.89%, median was 2.27%
# % of True in dataset 47.05% resulted in 25.99% and median 18.87%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For adjustedAlpha1Year, yCutoff = 0.03, taken used - 5675 is 44.15%
# Mean was 4.41%, median was 0.68%
# % of True in dataset 45.45% resulted in 26.82% and median 19.71%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For adjustedAlpha1Year, yCutoff = 0.03, taken used - 265 is 2.06%
# Mean was 6.74%, median was 3.4%
# % of True in dataset 45.45% resulted in 26.82% and median 19.71%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For adjustedAlpha1Year, yCutoff = 0.05, taken used - 5428 is 42.22%
# Mean was 3.89%, median was 0.37%
# % of True in dataset 42.25% resulted in 28.54% and median 21.23%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For adjustedAlpha1Year, yCutoff = 0.05, taken used - 82 is 0.64%
# Mean was 9.66%, median was 8.61%
# % of True in dataset 42.25% resulted in 28.54% and median 21.23%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For adjustedAlpha1Year, yCutoff = 0.07, taken used - 5108 is 39.739999999999995%
# Mean was 4.49%, median was 1.07%
# % of True in dataset 39.49% resulted in 30.11% and median 22.69%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For adjustedAlpha1Year, yCutoff = 0.07, taken used - 42 is 0.33%
# Mean was 6.6%, median was -5.71%
# % of True in dataset 39.49% resulted in 30.11% and median 22.69%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For adjustedAlpha1Year, yCutoff = 0.1, taken used - 4653 is 36.199999999999996%
# Mean was 5.31%, median was 1.21%
# % of True in dataset 35.05% resulted in 32.85% and median 25.22%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For adjustedAlpha1Year, yCutoff = 0.1, taken used - 13 is 0.1%
# Mean was -12.98%, median was -15.67%
# % of True in dataset 35.05% resulted in 32.85% and median 25.22%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For adjustedAlpha1Year, yCutoff = 0.15, taken used - 3950 is 30.73%
# Mean was 6.59%, median was 2.03%
# % of True in dataset 27.97% resulted in 38.0% and median 29.57%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For adjustedAlpha1Year, yCutoff = 0.15, taken used - 14 is 0.11%
# Mean was 10.86%, median was 6.65%
# % of True in dataset 27.97% resulted in 38.0% and median 29.57%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For adjustedAlpha1Year, yCutoff = 0.2, taken used - 3190 is 24.82%
# Mean was 4.04%, median was 0.98%
# % of True in dataset 22.34% resulted in 43.19% and median 34.04%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For adjustedAlpha1Year, yCutoff = 0.2, taken used - 9 is 0.06999999999999999%
# Mean was 57.11%, median was 78.29%
# % of True in dataset 22.34% resulted in 43.19% and median 34.04%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For adjustedAlpha1Year, yCutoff = 0.25, taken used - 2623 is 20.4%
# Mean was 3.62%, median was -0.14%
# % of True in dataset 17.68% resulted in 48.65% and median 38.74%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For adjustedAlpha1Year, yCutoff = 0.25, taken used - 0 is 0.0%
# Mean was nan%, median was nan%
# % of True in dataset 17.68% resulted in 48.65% and median 38.74%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For adjustedAlpha1Year, yCutoff = 0.35, taken used - 1631 is 12.690000000000001%
# Mean was 6.86%, median was 0.18%
# % of True in dataset 10.6% resulted in 61.4% and median 49.83%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For adjustedAlpha1Year, yCutoff = 0.35, taken used - 0 is 0.0%
# Mean was nan%, median was nan%
# % of True in dataset 10.6% resulted in 61.4% and median 49.83%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For equalAlpha1Year, yCutoff = 0.0, taken used - 5528 is 43.0%
# Mean was 2.36%, median was -1.23%
# % of True in dataset 45.97% resulted in 23.22% and median 15.71%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For equalAlpha1Year, yCutoff = 0.0, taken used - 388 is 3.02%
# Mean was 3.43%, median was -2.81%
# % of True in dataset 45.97% resulted in 23.22% and median 15.71%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For equalAlpha1Year, yCutoff = 0.01, taken used - 5532 is 43.03%
# Mean was 2.82%, median was -0.22%
# % of True in dataset 44.37% resulted in 24.04% and median 16.39%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For equalAlpha1Year, yCutoff = 0.01, taken used - 187 is 1.4500000000000002%
# Mean was 1.92%, median was -2.73%
# % of True in dataset 44.37% resulted in 24.04% and median 16.39%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For equalAlpha1Year, yCutoff = 0.02, taken used - 5370 is 41.77%
# Mean was 2.09%, median was -1.7%
# % of True in dataset 42.56% resulted in 25.0% and median 17.25%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For equalAlpha1Year, yCutoff = 0.02, taken used - 111 is 0.86%
# Mean was 3.23%, median was 0.75%
# % of True in dataset 42.56% resulted in 25.0% and median 17.25%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For equalAlpha1Year, yCutoff = 0.03, taken used - 5102 is 39.69%
# Mean was 1.94%, median was -1.63%
# % of True in dataset 40.77% resulted in 25.99% and median 18.12%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For equalAlpha1Year, yCutoff = 0.03, taken used - 86 is 0.67%
# Mean was 2.21%, median was -3.26%
# % of True in dataset 40.77% resulted in 25.99% and median 18.12%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For equalAlpha1Year, yCutoff = 0.05, taken used - 4950 is 38.51%
# Mean was 3.37%, median was -0.71%
# % of True in dataset 37.43% resulted in 27.95% and median 19.96%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For equalAlpha1Year, yCutoff = 0.05, taken used - 20 is 0.16%
# Mean was -11.44%, median was -16.92%
# % of True in dataset 37.43% resulted in 27.95% and median 19.96%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For equalAlpha1Year, yCutoff = 0.07, taken used - 4331 is 33.69%
# Mean was 1.52%, median was -1.97%
# % of True in dataset 34.4% resulted in 29.89% and median 21.92%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For equalAlpha1Year, yCutoff = 0.07, taken used - 7 is 0.05%
# Mean was -22.15%, median was -25.91%
# % of True in dataset 34.4% resulted in 29.89% and median 21.92%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For equalAlpha1Year, yCutoff = 0.1, taken used - 4107 is 31.95%
# Mean was 1.8%, median was -2.07%
# % of True in dataset 29.99% resulted in 33.04% and median 24.73%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For equalAlpha1Year, yCutoff = 0.1, taken used - 3 is 0.02%
# Mean was -31.92%, median was -32.4%
# % of True in dataset 29.99% resulted in 33.04% and median 24.73%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For equalAlpha1Year, yCutoff = 0.15, taken used - 3304 is 25.7%
# Mean was 1.8%, median was -1.43%
# % of True in dataset 23.91% resulted in 38.29% and median 29.15%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For equalAlpha1Year, yCutoff = 0.15, taken used - 6 is 0.05%
# Mean was 51.08%, median was 51.08%
# % of True in dataset 23.91% resulted in 38.29% and median 29.15%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For equalAlpha1Year, yCutoff = 0.2, taken used - 2533 is 19.7%
# Mean was 2.93%, median was -2.31%
# % of True in dataset 18.67% resulted in 44.18% and median 34.53%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For equalAlpha1Year, yCutoff = 0.2, taken used - 0 is 0.0%
# Mean was nan%, median was nan%
# % of True in dataset 18.67% resulted in 44.18% and median 34.53%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For equalAlpha1Year, yCutoff = 0.25, taken used - 2223 is 17.29%
# Mean was 4.83%, median was -0.15%
# % of True in dataset 14.79% resulted in 49.86% and median 39.29%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For equalAlpha1Year, yCutoff = 0.25, taken used - 0 is 0.0%
# Mean was nan%, median was nan%
# % of True in dataset 14.79% resulted in 49.86% and median 39.29%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For equalAlpha1Year, yCutoff = 0.35, taken used - 1553 is 12.08%
# Mean was 3.07%, median was -1.85%
# % of True in dataset 9.19% resulted in 62.35% and median 50.26%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For equalAlpha1Year, yCutoff = 0.35, taken used - 0 is 0.0%
# Mean was nan%, median was nan%
# % of True in dataset 9.19% resulted in 62.35% and median 50.26%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For equalAdjustedAlpha1Year, yCutoff = 0.0, taken used - 5688 is 44.25%
# Mean was 2.17%, median was -1.19%
# % of True in dataset 46.01% resulted in 23.34% and median 15.97%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For equalAdjustedAlpha1Year, yCutoff = 0.0, taken used - 336 is 2.6100000000000003%
# Mean was 7.22%, median was 1.11%
# % of True in dataset 46.01% resulted in 23.34% and median 15.97%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For equalAdjustedAlpha1Year, yCutoff = 0.01, taken used - 5289 is 41.14%
# Mean was 1.26%, median was -1.19%
# % of True in dataset 44.38% resulted in 24.18% and median 16.6%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For equalAdjustedAlpha1Year, yCutoff = 0.01, taken used - 179 is 1.39%
# Mean was 5.78%, median was 1.02%
# % of True in dataset 44.38% resulted in 24.18% and median 16.6%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For equalAdjustedAlpha1Year, yCutoff = 0.02, taken used - 5320 is 41.38%
# Mean was 2.3%, median was -1.0%
# % of True in dataset 42.71% resulted in 25.06% and median 17.33%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For equalAdjustedAlpha1Year, yCutoff = 0.02, taken used - 111 is 0.86%
# Mean was 5.5%, median was 2.42%
# % of True in dataset 42.71% resulted in 25.06% and median 17.33%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For equalAdjustedAlpha1Year, yCutoff = 0.03, taken used - 5223 is 40.63%
# Mean was 2.84%, median was -0.87%
# % of True in dataset 41.04% resulted in 25.98% and median 18.12%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For equalAdjustedAlpha1Year, yCutoff = 0.03, taken used - 46 is 0.36%
# Mean was -0.87%, median was -9.25%
# % of True in dataset 41.04% resulted in 25.98% and median 18.12%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For equalAdjustedAlpha1Year, yCutoff = 0.05, taken used - 4945 is 38.47%
# Mean was 2.78%, median was -0.98%
# % of True in dataset 37.83% resulted in 27.85% and median 19.94%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For equalAdjustedAlpha1Year, yCutoff = 0.05, taken used - 28 is 0.22%
# Mean was -8.27%, median was -12.97%
# % of True in dataset 37.83% resulted in 27.85% and median 19.94%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For equalAdjustedAlpha1Year, yCutoff = 0.07, taken used - 4683 is 36.43%
# Mean was 2.55%, median was -0.62%
# % of True in dataset 34.55% resulted in 29.92% and median 21.94%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For equalAdjustedAlpha1Year, yCutoff = 0.07, taken used - 13 is 0.1%
# Mean was -15.04%, median was -17.75%
# % of True in dataset 34.55% resulted in 29.92% and median 21.94%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For equalAdjustedAlpha1Year, yCutoff = 0.1, taken used - 4153 is 32.31%
# Mean was 2.9%, median was -0.45%
# % of True in dataset 30.35% resulted in 32.88% and median 24.63%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For equalAdjustedAlpha1Year, yCutoff = 0.1, taken used - 3 is 0.02%
# Mean was -33.85%, median was -34.31%
# % of True in dataset 30.35% resulted in 32.88% and median 24.63%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For equalAdjustedAlpha1Year, yCutoff = 0.15, taken used - 3468 is 26.979999999999997%
# Mean was 2.77%, median was -1.0%
# % of True in dataset 24.02% resulted in 38.28% and median 28.81%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For equalAdjustedAlpha1Year, yCutoff = 0.15, taken used - 0 is 0.0%
# Mean was nan%, median was nan%
# % of True in dataset 24.02% resulted in 38.28% and median 28.81%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For equalAdjustedAlpha1Year, yCutoff = 0.2, taken used - 2546 is 19.81%
# Mean was 2.71%, median was -1.91%
# % of True in dataset 18.9% resulted in 43.96% and median 34.4%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For equalAdjustedAlpha1Year, yCutoff = 0.2, taken used - 6 is 0.05%
# Mean was 48.97%, median was 48.97%
# % of True in dataset 18.9% resulted in 43.96% and median 34.4%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For equalAdjustedAlpha1Year, yCutoff = 0.25, taken used - 2088 is 16.24%
# Mean was 4.21%, median was -1.1%
# % of True in dataset 14.9% resulted in 49.73% and median 39.05%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For equalAdjustedAlpha1Year, yCutoff = 0.25, taken used - 0 is 0.0%
# Mean was nan%, median was nan%
# % of True in dataset 14.9% resulted in 49.73% and median 39.05%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For equalAdjustedAlpha1Year, yCutoff = 0.35, taken used - 1463 is 11.379999999999999%
# Mean was 2.61%, median was -2.06%
# % of True in dataset 9.17% resulted in 62.54% and median 50.33%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For equalAdjustedAlpha1Year, yCutoff = 0.35, taken used - 0 is 0.0%
# Mean was nan%, median was nan%
# % of True in dataset 9.17% resulted in 62.54% and median 50.33%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For alpha2Year, yCutoff = 0.0, taken used - 5802 is 45.129999999999995%
# Mean was 2.37%, median was -5.9%
# % of True in dataset 39.49% resulted in 46.87% and median 26.78%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For alpha2Year, yCutoff = 0.0, taken used - 2554 is 19.869999999999997%
# Mean was 12.56%, median was -2.54%
# % of True in dataset 39.49% resulted in 46.87% and median 26.78%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For alpha2Year, yCutoff = 0.01, taken used - 5914 is 46.01%
# Mean was -0.37%, median was -7.92%
# % of True in dataset 38.33% resulted in 48.28% and median 28.26%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For alpha2Year, yCutoff = 0.01, taken used - 1693 is 13.170000000000002%
# Mean was 15.47%, median was -0.43%
# % of True in dataset 38.33% resulted in 48.28% and median 28.26%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For alpha2Year, yCutoff = 0.02, taken used - 5738 is 44.64%
# Mean was 1.26%, median was -7.25%
# % of True in dataset 37.36% resulted in 49.48% and median 29.29%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For alpha2Year, yCutoff = 0.02, taken used - 1155 is 8.98%
# Mean was 18.93%, median was 0.72%
# % of True in dataset 37.36% resulted in 49.48% and median 29.29%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For alpha2Year, yCutoff = 0.03, taken used - 5591 is 43.49%
# Mean was 3.64%, median was -6.14%
# % of True in dataset 36.45% resulted in 50.66% and median 30.12%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For alpha2Year, yCutoff = 0.03, taken used - 572 is 4.45%
# Mean was 33.22%, median was 3.95%
# % of True in dataset 36.45% resulted in 50.66% and median 30.12%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For alpha2Year, yCutoff = 0.05, taken used - 4964 is 38.62%
# Mean was 3.76%, median was -4.84%
# % of True in dataset 34.5% resulted in 53.3% and median 32.25%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For alpha2Year, yCutoff = 0.05, taken used - 158 is 1.23%
# Mean was 64.18%, median was 16.47%
# % of True in dataset 34.5% resulted in 53.3% and median 32.25%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For alpha2Year, yCutoff = 0.07, taken used - 4891 is 38.05%
# Mean was 4.0%, median was -3.81%
# % of True in dataset 32.8% resulted in 55.75% and median 33.79%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For alpha2Year, yCutoff = 0.07, taken used - 56 is 0.44%
# Mean was 33.52%, median was -5.96%
# % of True in dataset 32.8% resulted in 55.75% and median 33.79%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For alpha2Year, yCutoff = 0.1, taken used - 4702 is 36.58%
# Mean was 7.47%, median was -2.96%
# % of True in dataset 30.38% resulted in 59.52% and median 36.96%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For alpha2Year, yCutoff = 0.1, taken used - 13 is 0.1%
# Mean was 57.33%, median was 2.71%
# % of True in dataset 30.38% resulted in 59.52% and median 36.96%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For alpha2Year, yCutoff = 0.15, taken used - 3886 is 30.23%
# Mean was 7.5%, median was -3.8%
# % of True in dataset 26.76% resulted in 65.89% and median 42.36%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For alpha2Year, yCutoff = 0.15, taken used - 6 is 0.05%
# Mean was 124.35%, median was 113.87%
# % of True in dataset 26.76% resulted in 65.89% and median 42.36%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For alpha2Year, yCutoff = 0.2, taken used - 3392 is 26.39%
# Mean was 9.37%, median was -2.53%
# % of True in dataset 23.56% resulted in 72.48% and median 48.32%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For alpha2Year, yCutoff = 0.2, taken used - 3 is 0.02%
# Mean was -28.9%, median was -27.54%
# % of True in dataset 23.56% resulted in 72.48% and median 48.32%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For alpha2Year, yCutoff = 0.25, taken used - 3021 is 23.5%
# Mean was 6.64%, median was -3.86%
# % of True in dataset 20.72% resulted in 79.34% and median 53.28%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For alpha2Year, yCutoff = 0.25, taken used - 3 is 0.02%
# Mean was -28.9%, median was -27.54%
# % of True in dataset 20.72% resulted in 79.34% and median 53.28%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For alpha2Year, yCutoff = 0.35, taken used - 2605 is 20.26%
# Mean was 6.53%, median was -2.93%
# % of True in dataset 15.92% resulted in 94.21% and median 64.93%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For alpha2Year, yCutoff = 0.35, taken used - 0 is 0.0%
# Mean was nan%, median was nan%
# % of True in dataset 15.92% resulted in 94.21% and median 64.93%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For adjustedAlpha2Year, yCutoff = 0.0, taken used - 5748 is 44.71%
# Mean was 5.9%, median was -4.63%
# % of True in dataset 40.08% resulted in 46.8% and median 26.36%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For adjustedAlpha2Year, yCutoff = 0.0, taken used - 2614 is 20.330000000000002%
# Mean was 12.09%, median was -1.79%
# % of True in dataset 40.08% resulted in 46.8% and median 26.36%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For adjustedAlpha2Year, yCutoff = 0.01, taken used - 5649 is 43.94%
# Mean was 5.37%, median was -4.15%
# % of True in dataset 38.89% resulted in 48.22% and median 27.69%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For adjustedAlpha2Year, yCutoff = 0.01, taken used - 1969 is 15.32%
# Mean was 13.92%, median was -0.95%
# % of True in dataset 38.89% resulted in 48.22% and median 27.69%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For adjustedAlpha2Year, yCutoff = 0.02, taken used - 5555 is 43.21%
# Mean was 4.93%, median was -4.71%
# % of True in dataset 37.96% resulted in 49.36% and median 28.66%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For adjustedAlpha2Year, yCutoff = 0.02, taken used - 1231 is 9.58%
# Mean was 18.43%, median was -0.44%
# % of True in dataset 37.96% resulted in 49.36% and median 28.66%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For adjustedAlpha2Year, yCutoff = 0.03, taken used - 5449 is 42.39%
# Mean was 4.72%, median was -4.8%
# % of True in dataset 36.89% resulted in 50.73% and median 29.91%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For adjustedAlpha2Year, yCutoff = 0.03, taken used - 736 is 5.7299999999999995%
# Mean was 28.62%, median was 3.04%
# % of True in dataset 36.89% resulted in 50.73% and median 29.91%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For adjustedAlpha2Year, yCutoff = 0.05, taken used - 5316 is 41.349999999999994%
# Mean was 4.93%, median was -4.95%
# % of True in dataset 35.14% resulted in 53.05% and median 31.75%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For adjustedAlpha2Year, yCutoff = 0.05, taken used - 240 is 1.87%
# Mean was 41.25%, median was -0.33%
# % of True in dataset 35.14% resulted in 53.05% and median 31.75%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For adjustedAlpha2Year, yCutoff = 0.07, taken used - 5063 is 39.39%
# Mean was 5.83%, median was -4.85%
# % of True in dataset 33.42% resulted in 55.47% and median 33.7%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For adjustedAlpha2Year, yCutoff = 0.07, taken used - 50 is 0.38999999999999996%
# Mean was 58.92%, median was -10.72%
# % of True in dataset 33.42% resulted in 55.47% and median 33.7%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For adjustedAlpha2Year, yCutoff = 0.1, taken used - 4801 is 37.35%
# Mean was 6.49%, median was -3.82%
# % of True in dataset 30.98% resulted in 59.17% and median 36.64%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For adjustedAlpha2Year, yCutoff = 0.1, taken used - 19 is 0.15%
# Mean was 25.68%, median was -18.02%
# % of True in dataset 30.98% resulted in 59.17% and median 36.64%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For adjustedAlpha2Year, yCutoff = 0.15, taken used - 4296 is 33.42%
# Mean was 5.53%, median was -5.95%
# % of True in dataset 27.17% resulted in 65.71% and median 42.14%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For adjustedAlpha2Year, yCutoff = 0.15, taken used - 4 is 0.03%
# Mean was 37.4%, median was -28.62%
# % of True in dataset 27.17% resulted in 65.71% and median 42.14%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For adjustedAlpha2Year, yCutoff = 0.2, taken used - 3756 is 29.220000000000002%
# Mean was 6.34%, median was -4.43%
# % of True in dataset 23.75% resulted in 72.68% and median 47.95%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For adjustedAlpha2Year, yCutoff = 0.2, taken used - 3 is 0.02%
# Mean was -32.35%, median was -30.96%
# % of True in dataset 23.75% resulted in 72.68% and median 47.95%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For adjustedAlpha2Year, yCutoff = 0.25, taken used - 3262 is 25.380000000000003%
# Mean was 8.47%, median was -5.02%
# % of True in dataset 20.79% resulted in 79.81% and median 53.09%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For adjustedAlpha2Year, yCutoff = 0.25, taken used - 3 is 0.02%
# Mean was -32.35%, median was -30.96%
# % of True in dataset 20.79% resulted in 79.81% and median 53.09%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For adjustedAlpha2Year, yCutoff = 0.35, taken used - 2483 is 19.32%
# Mean was 7.57%, median was -5.32%
# % of True in dataset 16.21% resulted in 93.96% and median 64.34%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For adjustedAlpha2Year, yCutoff = 0.35, taken used - 0 is 0.0%
# Mean was nan%, median was nan%
# % of True in dataset 16.21% resulted in 93.96% and median 64.34%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For equalAlpha2Year, yCutoff = 0.0, taken used - 5120 is 39.83%
# Mean was 5.04%, median was -6.44%
# % of True in dataset 39.26% resulted in 48.23% and median 27.85%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For equalAlpha2Year, yCutoff = 0.0, taken used - 65 is 0.51%
# Mean was 157.42%, median was 2.54%
# % of True in dataset 39.26% resulted in 48.23% and median 27.85%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For equalAlpha2Year, yCutoff = 0.01, taken used - 4877 is 37.940000000000005%
# Mean was 5.4%, median was -5.84%
# % of True in dataset 38.35% resulted in 49.36% and median 28.74%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For equalAlpha2Year, yCutoff = 0.01, taken used - 45 is 0.35000000000000003%
# Mean was 182.17%, median was 13.74%
# % of True in dataset 38.35% resulted in 49.36% and median 28.74%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For equalAlpha2Year, yCutoff = 0.02, taken used - 4977 is 38.72%
# Mean was 5.05%, median was -5.46%
# % of True in dataset 37.57% resulted in 50.35% and median 29.56%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For equalAlpha2Year, yCutoff = 0.02, taken used - 31 is 0.24%
# Mean was 130.66%, median was -6.42%
# % of True in dataset 37.57% resulted in 50.35% and median 29.56%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For equalAlpha2Year, yCutoff = 0.03, taken used - 4695 is 36.52%
# Mean was 4.84%, median was -4.45%
# % of True in dataset 36.58% resulted in 51.64% and median 30.67%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For equalAlpha2Year, yCutoff = 0.03, taken used - 20 is 0.16%
# Mean was 91.07%, median was 8.66%
# % of True in dataset 36.58% resulted in 51.64% and median 30.67%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For equalAlpha2Year, yCutoff = 0.05, taken used - 4854 is 37.76%
# Mean was 9.27%, median was -3.37%
# % of True in dataset 34.91% resulted in 53.93% and median 32.71%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For equalAlpha2Year, yCutoff = 0.05, taken used - 12 is 0.09%
# Mean was 76.95%, median was 26.28%
# % of True in dataset 34.91% resulted in 53.93% and median 32.71%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For equalAlpha2Year, yCutoff = 0.07, taken used - 4304 is 33.48%
# Mean was 6.17%, median was -4.44%
# % of True in dataset 33.32% resulted in 56.22% and median 34.46%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For equalAlpha2Year, yCutoff = 0.07, taken used - 6 is 0.05%
# Mean was 125.46%, median was 114.49%
# % of True in dataset 33.32% resulted in 56.22% and median 34.46%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For equalAlpha2Year, yCutoff = 0.1, taken used - 3664 is 28.499999999999996%
# Mean was 8.37%, median was -4.39%
# % of True in dataset 30.67% resulted in 60.35% and median 38.2%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For equalAlpha2Year, yCutoff = 0.1, taken used - 6 is 0.05%
# Mean was 125.46%, median was 114.49%
# % of True in dataset 30.67% resulted in 60.35% and median 38.2%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For equalAlpha2Year, yCutoff = 0.15, taken used - 3349 is 26.05%
# Mean was 7.92%, median was -4.18%
# % of True in dataset 26.9% resulted in 67.05% and median 43.91%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For equalAlpha2Year, yCutoff = 0.15, taken used - 3 is 0.02%
# Mean was -31.71%, median was -29.72%
# % of True in dataset 26.9% resulted in 67.05% and median 43.91%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For equalAlpha2Year, yCutoff = 0.2, taken used - 2966 is 23.07%
# Mean was 6.47%, median was -5.37%
# % of True in dataset 23.88% resulted in 73.32% and median 49.21%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For equalAlpha2Year, yCutoff = 0.2, taken used - 0 is 0.0%
# Mean was nan%, median was nan%
# % of True in dataset 23.88% resulted in 73.32% and median 49.21%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For equalAlpha2Year, yCutoff = 0.25, taken used - 2466 is 19.18%
# Mean was 16.53%, median was 1.2%
# % of True in dataset 21.09% resulted in 80.08% and median 54.94%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For equalAlpha2Year, yCutoff = 0.25, taken used - 0 is 0.0%
# Mean was nan%, median was nan%
# % of True in dataset 21.09% resulted in 80.08% and median 54.94%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For equalAlpha2Year, yCutoff = 0.35, taken used - 2141 is 16.650000000000002%
# Mean was 13.43%, median was -0.74%
# % of True in dataset 16.49% resulted in 94.12% and median 64.4%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For equalAlpha2Year, yCutoff = 0.35, taken used - 0 is 0.0%
# Mean was nan%, median was nan%
# % of True in dataset 16.49% resulted in 94.12% and median 64.4%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For equalAdjustedAlpha2Year, yCutoff = 0.0, taken used - 4881 is 37.97%
# Mean was 8.79%, median was -5.42%
# % of True in dataset 39.55% resulted in 47.97% and median 27.58%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For equalAdjustedAlpha2Year, yCutoff = 0.0, taken used - 63 is 0.49%
# Mean was 122.43%, median was -6.91%
# % of True in dataset 39.55% resulted in 47.97% and median 27.58%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For equalAdjustedAlpha2Year, yCutoff = 0.01, taken used - 4884 is 37.99%
# Mean was 6.93%, median was -4.72%
# % of True in dataset 38.65% resulted in 49.07% and median 28.51%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For equalAdjustedAlpha2Year, yCutoff = 0.01, taken used - 53 is 0.41000000000000003%
# Mean was 120.93%, median was -6.91%
# % of True in dataset 38.65% resulted in 49.07% and median 28.51%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For equalAdjustedAlpha2Year, yCutoff = 0.02, taken used - 4937 is 38.41%
# Mean was 5.76%, median was -6.74%
# % of True in dataset 37.79% resulted in 50.16% and median 29.4%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For equalAdjustedAlpha2Year, yCutoff = 0.02, taken used - 26 is 0.2%
# Mean was 114.5%, median was -19.71%
# % of True in dataset 37.79% resulted in 50.16% and median 29.4%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For equalAdjustedAlpha2Year, yCutoff = 0.03, taken used - 4739 is 36.870000000000005%
# Mean was 4.84%, median was -4.67%
# % of True in dataset 36.74% resulted in 51.52% and median 30.77%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For equalAdjustedAlpha2Year, yCutoff = 0.03, taken used - 21 is 0.16%
# Mean was 140.05%, median was -20.47%
# % of True in dataset 36.74% resulted in 51.52% and median 30.77%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For equalAdjustedAlpha2Year, yCutoff = 0.05, taken used - 4369 is 33.989999999999995%
# Mean was 8.29%, median was -4.48%
# % of True in dataset 35.0% resulted in 53.88% and median 32.43%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For equalAdjustedAlpha2Year, yCutoff = 0.05, taken used - 8 is 0.06%
# Mean was -31.11%, median was -32.22%
# % of True in dataset 35.0% resulted in 53.88% and median 32.43%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For equalAdjustedAlpha2Year, yCutoff = 0.07, taken used - 4416 is 34.35%
# Mean was 11.26%, median was -1.5%
# % of True in dataset 33.19% resulted in 56.5% and median 34.86%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For equalAdjustedAlpha2Year, yCutoff = 0.07, taken used - 6 is 0.05%
# Mean was 121.34%, median was 110.4%
# % of True in dataset 33.19% resulted in 56.5% and median 34.86%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For equalAdjustedAlpha2Year, yCutoff = 0.1, taken used - 3662 is 28.49%
# Mean was 7.27%, median was -3.64%
# % of True in dataset 30.76% resulted in 60.28% and median 37.76%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For equalAdjustedAlpha2Year, yCutoff = 0.1, taken used - 3 is 0.02%
# Mean was -35.62%, median was -33.61%
# % of True in dataset 30.76% resulted in 60.28% and median 37.76%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For equalAdjustedAlpha2Year, yCutoff = 0.15, taken used - 3463 is 26.939999999999998%
# Mean was 10.66%, median was -3.12%
# % of True in dataset 26.95% resulted in 67.08% and median 43.81%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For equalAdjustedAlpha2Year, yCutoff = 0.15, taken used - 3 is 0.02%
# Mean was -35.62%, median was -33.61%
# % of True in dataset 26.95% resulted in 67.08% and median 43.81%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For equalAdjustedAlpha2Year, yCutoff = 0.2, taken used - 3319 is 25.82%
# Mean was 9.86%, median was -3.8%
# % of True in dataset 23.66% resulted in 73.99% and median 49.03%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For equalAdjustedAlpha2Year, yCutoff = 0.2, taken used - 0 is 0.0%
# Mean was nan%, median was nan%
# % of True in dataset 23.66% resulted in 73.99% and median 49.03%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For equalAdjustedAlpha2Year, yCutoff = 0.25, taken used - 2799 is 21.77%
# Mean was 7.39%, median was -4.48%
# % of True in dataset 21.0% resulted in 80.53% and median 54.32%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For equalAdjustedAlpha2Year, yCutoff = 0.25, taken used - 0 is 0.0%
# Mean was nan%, median was nan%
# % of True in dataset 21.0% resulted in 80.53% and median 54.32%
# -----------
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# MODEL tree
# For equalAdjustedAlpha2Year, yCutoff = 0.35, taken used - 2311 is 17.98%
# Mean was 12.75%, median was -1.69%
# % of True in dataset 16.51% resulted in 94.31% and median 64.42%
# -----------
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# MODEL svc
# For equalAdjustedAlpha2Year, yCutoff = 0.35, taken used - 0 is 0.0%
# Mean was nan%, median was nan%
# % of True in dataset 16.51% resulted in 94.31% and median 64.42%
# -----------

# %%
def drawFrom1results(ax1, ax2, resultsToPlot, yLabel, title=''):
    toPlot = resultsToPlot[yLabel]['svc']
    ax1.plot(x, [d['mean'] for d in toPlot], color='red', label='mean')
    ax1.plot(x, [d['median'] for d in toPlot], color='green', label='median')
    
    ax1.legend(loc='upper left')
    ax1.grid(True)
    
    ax1b = ax1.twinx()
    ax1b.plot(x, [d['taken'] for d in toPlot], color='blue', label='taken')
    ax1b.legend(loc='upper right')
    ax1b.set_yscale('log')
    ax1.set_xscale('log')
    
    plt.title(f'Cutoff influence for {yLabel} SVM {title}')
    
    toPlot = resultsToPlot[yLabel]['tree']
    
    ax2.plot(x, [d['mean'] for d in toPlot], color='red', label='mean')
    ax2.plot(x, [d['median'] for d in toPlot], color='green', label='median')
    
    ax2.legend(loc='upper left')
    ax2.grid(True)
    
    ax2b = ax2.twinx()
    ax2b.plot(x, [d['taken'] for d in toPlot], color='blue', label='taken')
    ax2b.legend(loc='upper right')
    ax2b.set_yscale('log')
    plt.title(f'Cutoff influence for {yLabel} TREE {title}')

# %%
x = cutoffs
for yLabel in resultsToPlot.keys():
    fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(16, 4))
    drawFrom1results(ax1, ax2, resultsToPlot, yLabel)
    plt.show()
