# %%
from headers import *
import pandas as pd
import numpy as np
from utils.custom_train_test_split import *
import matplotlib.pyplot as plt
import json
from sklearn.model_selection import train_test_split
from analysis.training_helper import trainPipeline, drawFrom1results

# %%
# SEEDS CHANGED IN training_helper.py
cutoffs = [0.0, 0.01, 0.02, 0.03, 0.05, 0.07, 0.10, 0.15, 0.20, 0.25, 0.35]
files = ['../data/deduplicated/combined_inner_ticker.csv']
thresholds = [70, 80, 90, 95]

# %%
trainDf, testDf = per_year_train_test_split(files, format='%Y-%m-%d')
resultsToPlotYear = trainPipeline(cutoffs, yAlpha, trainDf, testDf, thresholds)
balancedResultsYear = trainPipeline(cutoffs, yAlpha, trainDf, testDf, thresholds, isBalanced=True)

# trainDfCompany, testDfCompany = custom_train_test_split(files)
# resultsToPlotCompany = trainPipeline(cutoffs, yAlpha, trainDfCompany, testDfCompany, thresholds)
# balancedResultsCompany = trainPipeline(cutoffs, yAlpha, trainDfCompany, testDfCompany, thresholds, isBalanced=True)

# trainDfRand, testDfRand = train_test_split(joinDfs(files))
# resultsToPlotRand = trainPipeline(cutoffs, yAlpha, trainDfRand, testDfRand, thresholds)
# balancedResultsRand = trainPipeline(cutoffs, yAlpha, trainDfRand, testDfRand, thresholds, isBalanced=True)
# Out:
# -----------------
# % of True in dataset 50.92% resulted in 24.61% and median 17.28%
# MODEL tree
# For alpha1Year, yCutoff = 0.0, taken used - 4990 is 47.27%
# Mean was 4.9%, median was 1.84%
# MODEL svc
# For alpha1Year, yCutoff = 0.0, taken used - 3937 is 37.3%
# Mean was 5.07%, median was 1.38%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 5.68%, median was 1.46%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 6.61%, median was 1.74%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 7.84%, median was 1.43%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 3.27%, median was -2.77%
# -----------------
# -----------------
# % of True in dataset 49.42% resulted in 25.34% and median 18.09%
# MODEL tree
# For alpha1Year, yCutoff = 0.01, taken used - 4868 is 46.12%
# Mean was 4.63%, median was 1.45%
# MODEL svc
# For alpha1Year, yCutoff = 0.01, taken used - 2517 is 23.84%
# Mean was 6.36%, median was 1.95%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 5.6%, median was 1.4%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 6.62%, median was 2.12%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 7.9%, median was 1.91%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 2.43%, median was -1.74%
# -----------------
# -----------------
# % of True in dataset 47.86% resulted in 26.12% and median 18.74%
# MODEL tree
# For alpha1Year, yCutoff = 0.02, taken used - 4650 is 44.05%
# Mean was 4.67%, median was 1.12%
# MODEL svc
# For alpha1Year, yCutoff = 0.02, taken used - 1542 is 14.610000000000001%
# Mean was 7.13%, median was 1.82%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 5.92%, median was 1.78%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 6.7%, median was 2.09%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 8.18%, median was 1.38%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 4.55%, median was -1.32%
# -----------------
# -----------------
# % of True in dataset 46.06% resulted in 27.04% and median 19.6%
# MODEL tree
# For alpha1Year, yCutoff = 0.03, taken used - 4578 is 43.37%
# Mean was 5.42%, median was 1.96%
# MODEL svc
# For alpha1Year, yCutoff = 0.03, taken used - 917 is 8.690000000000001%
# Mean was 7.43%, median was 1.95%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 5.73%, median was 1.7%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 6.19%, median was 1.95%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 7.53%, median was 1.43%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 3.93%, median was -1.86%
# -----------------
# -----------------
# % of True in dataset 42.97% resulted in 28.7% and median 21.14%
# MODEL tree
# For alpha1Year, yCutoff = 0.05, taken used - 4323 is 40.949999999999996%
# Mean was 5.12%, median was 1.6%
# MODEL svc
# For alpha1Year, yCutoff = 0.05, taken used - 325 is 3.08%
# Mean was 2.88%, median was -0.28%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 5.67%, median was 1.6%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 6.04%, median was 1.67%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 6.85%, median was 1.43%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 4.54%, median was 0.62%
# -----------------
# -----------------
# % of True in dataset 39.84% resulted in 30.48% and median 22.88%
# MODEL tree
# For alpha1Year, yCutoff = 0.07, taken used - 4243 is 40.2%
# Mean was 5.47%, median was 2.37%
# MODEL svc
# For alpha1Year, yCutoff = 0.07, taken used - 87 is 0.8200000000000001%
# Mean was 1.21%, median was -9.87%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 5.89%, median was 1.81%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 6.41%, median was 1.95%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 7.53%, median was 1.82%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 6.94%, median was 2.69%
# -----------------
# -----------------
# % of True in dataset 35.23% resulted in 33.35% and median 25.45%
# MODEL tree
# For alpha1Year, yCutoff = 0.1, taken used - 3772 is 35.730000000000004%
# Mean was 5.4%, median was 1.97%
# MODEL svc
# For alpha1Year, yCutoff = 0.1, taken used - 15 is 0.13999999999999999%
# Mean was 6.89%, median was -12.31%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 6.11%, median was 2.25%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 6.64%, median was 2.25%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 7.82%, median was 2.03%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 7.18%, median was 3.29%
# -----------------
# -----------------
# % of True in dataset 28.24% resulted in 38.53% and median 29.9%
# MODEL tree
# For alpha1Year, yCutoff = 0.15, taken used - 3086 is 29.23%
# Mean was 6.27%, median was 1.53%
# MODEL svc
# For alpha1Year, yCutoff = 0.15, taken used - 9 is 0.09%
# Mean was 9.79%, median was -13.9%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 6.12%, median was 2.25%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 6.19%, median was 2.16%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 8.49%, median was 2.68%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 8.01%, median was 4.09%
# -----------------
# -----------------
# % of True in dataset 22.51% resulted in 43.88% and median 34.47%
# MODEL tree
# For alpha1Year, yCutoff = 0.2, taken used - 2502 is 23.7%
# Mean was 6.47%, median was 2.68%
# MODEL svc
# For alpha1Year, yCutoff = 0.2, taken used - 4 is 0.04%
# Mean was 40.71%, median was 44.22%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 6.1%, median was 2.48%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 6.48%, median was 2.33%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 7.78%, median was 3.43%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 9.51%, median was 4.92%
# -----------------
# -----------------
# % of True in dataset 18.05% resulted in 49.17% and median 39.1%
# MODEL tree
# For alpha1Year, yCutoff = 0.25, taken used - 2046 is 19.38%
# Mean was 6.19%, median was 1.71%
# MODEL svc
# For alpha1Year, yCutoff = 0.25, taken used - 3 is 0.03%
# Mean was 58.91%, median was 80.06%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 5.88%, median was 2.2%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 6.54%, median was 2.55%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 7.44%, median was 3.4%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 9.0%, median was 4.19%
# -----------------
# -----------------
# % of True in dataset 10.94% resulted in 61.91% and median 49.66%
# MODEL tree
# For alpha1Year, yCutoff = 0.35, taken used - 1349 is 12.78%
# Mean was 5.71%, median was 1.27%
# MODEL svc
# For alpha1Year, yCutoff = 0.35, taken used - 0 is 0.0%
# Mean was nan%, median was nan%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 5.83%, median was 2.32%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 6.77%, median was 2.91%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 7.09%, median was 3.69%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 8.63%, median was 4.8%
# -----------------
# -----------------
# % of True in dataset 51.78% resulted in 24.8% and median 17.82%
# MODEL tree
# For adjustedAlpha1Year, yCutoff = 0.0, taken used - 4963 is 47.02%
# Mean was 5.87%, median was 1.87%
# MODEL svc
# For adjustedAlpha1Year, yCutoff = 0.0, taken used - 3882 is 36.78%
# Mean was 5.67%, median was 1.93%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 6.12%, median was 2.07%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 6.36%, median was 1.77%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 7.8%, median was 2.4%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 6.22%, median was 2.38%
# -----------------
# -----------------
# % of True in dataset 49.93% resulted in 25.7% and median 18.61%
# MODEL tree
# For adjustedAlpha1Year, yCutoff = 0.01, taken used - 4966 is 47.04%
# Mean was 5.18%, median was 2.01%
# MODEL svc
# For adjustedAlpha1Year, yCutoff = 0.01, taken used - 2502 is 23.7%
# Mean was 6.96%, median was 2.63%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 6.59%, median was 2.51%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 6.86%, median was 2.14%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 8.32%, median was 3.09%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 8.38%, median was 3.57%
# -----------------
# -----------------
# % of True in dataset 48.31% resulted in 26.51% and median 19.26%
# MODEL tree
# For adjustedAlpha1Year, yCutoff = 0.02, taken used - 4766 is 45.15%
# Mean was 5.32%, median was 1.89%
# MODEL svc
# For adjustedAlpha1Year, yCutoff = 0.02, taken used - 1364 is 12.920000000000002%
# Mean was 7.1%, median was 1.51%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 6.08%, median was 2.07%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 6.42%, median was 1.93%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 7.85%, median was 2.43%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 6.14%, median was 2.5%
# -----------------
# -----------------
# % of True in dataset 46.7% resulted in 27.34% and median 20.02%
# MODEL tree
# For adjustedAlpha1Year, yCutoff = 0.03, taken used - 4579 is 43.38%
# Mean was 5.25%, median was 2.0%
# MODEL svc
# For adjustedAlpha1Year, yCutoff = 0.03, taken used - 759 is 7.19%
# Mean was 9.17%, median was 4.17%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 5.96%, median was 2.33%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 6.13%, median was 1.59%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 8.62%, median was 2.86%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 7.08%, median was 3.48%
# -----------------
# -----------------
# % of True in dataset 43.53% resulted in 29.04% and median 21.6%
# MODEL tree
# For adjustedAlpha1Year, yCutoff = 0.05, taken used - 4367 is 41.370000000000005%
# Mean was 5.94%, median was 2.41%
# MODEL svc
# For adjustedAlpha1Year, yCutoff = 0.05, taken used - 228 is 2.16%
# Mean was 6.72%, median was 2.73%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 5.8%, median was 2.14%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 6.15%, median was 1.82%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 8.02%, median was 2.62%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 8.26%, median was 3.57%
# -----------------
# -----------------
# % of True in dataset 40.7% resulted in 30.64% and median 23.23%
# MODEL tree
# For adjustedAlpha1Year, yCutoff = 0.07, taken used - 4055 is 38.41%
# Mean was 5.74%, median was 2.0%
# MODEL svc
# For adjustedAlpha1Year, yCutoff = 0.07, taken used - 71 is 0.67%
# Mean was 5.34%, median was 2.73%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 6.11%, median was 2.43%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 6.03%, median was 1.64%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 8.7%, median was 3.09%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 7.99%, median was 3.97%
# -----------------
# -----------------
# % of True in dataset 36.17% resulted in 33.4% and median 25.57%
# MODEL tree
# For adjustedAlpha1Year, yCutoff = 0.1, taken used - 3374 is 31.96%
# Mean was 4.56%, median was 0.77%
# MODEL svc
# For adjustedAlpha1Year, yCutoff = 0.1, taken used - 29 is 0.27%
# Mean was 3.87%, median was -9.42%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 6.56%, median was 2.94%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 6.78%, median was 2.43%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 8.76%, median was 3.21%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 9.78%, median was 4.56%
# -----------------
# -----------------
# % of True in dataset 29.23% resulted in 38.37% and median 29.8%
# MODEL tree
# For adjustedAlpha1Year, yCutoff = 0.15, taken used - 3050 is 28.89%
# Mean was 5.56%, median was 1.98%
# MODEL svc
# For adjustedAlpha1Year, yCutoff = 0.15, taken used - 9 is 0.09%
# Mean was 8.13%, median was -15.67%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 5.71%, median was 2.2%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 6.73%, median was 2.7%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 8.4%, median was 3.6%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 8.6%, median was 3.75%
# -----------------
# -----------------
# % of True in dataset 23.38% resulted in 43.61% and median 34.29%
# MODEL tree
# For adjustedAlpha1Year, yCutoff = 0.2, taken used - 2473 is 23.43%
# Mean was 7.1%, median was 3.17%
# MODEL svc
# For adjustedAlpha1Year, yCutoff = 0.2, taken used - 3 is 0.03%
# Mean was 57.11%, median was 78.29%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 5.99%, median was 2.43%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 6.91%, median was 2.95%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 7.93%, median was 3.6%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 7.77%, median was 2.88%
# -----------------
# -----------------
# % of True in dataset 18.55% resulted in 49.11% and median 38.99%
# MODEL tree
# For adjustedAlpha1Year, yCutoff = 0.25, taken used - 1889 is 17.9%
# Mean was 5.02%, median was 0.39%
# MODEL svc
# For adjustedAlpha1Year, yCutoff = 0.25, taken used - 3 is 0.03%
# Mean was 57.11%, median was 78.29%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 5.83%, median was 2.42%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 6.71%, median was 3.02%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 7.13%, median was 3.53%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 7.73%, median was 3.28%
# -----------------
# -----------------
# % of True in dataset 11.27% resulted in 61.71% and median 49.75%
# MODEL tree
# For adjustedAlpha1Year, yCutoff = 0.35, taken used - 1409 is 13.350000000000001%
# Mean was 6.42%, median was 0.59%
# MODEL svc
# For adjustedAlpha1Year, yCutoff = 0.35, taken used - 0 is 0.0%
# Mean was nan%, median was nan%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 5.87%, median was 2.79%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 6.7%, median was 3.1%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 7.06%, median was 3.44%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 8.15%, median was 3.75%
# -----------------
# -----------------
# % of True in dataset 47.25% resulted in 23.79% and median 16.18%
# MODEL tree
# For equalAlpha1Year, yCutoff = 0.0, taken used - 4684 is 44.37%
# Mean was 3.82%, median was 0.22%
# MODEL svc
# For equalAlpha1Year, yCutoff = 0.0, taken used - 1100 is 10.42%
# Mean was 2.91%, median was -2.27%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 2.26%, median was -1.9%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 2.78%, median was -1.95%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 2.68%, median was -2.41%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was -0.42%, median was -6.6%
# -----------------
# -----------------
# % of True in dataset 45.59% resulted in 24.64% and median 16.97%
# MODEL tree
# For equalAlpha1Year, yCutoff = 0.01, taken used - 4589 is 43.47%
# Mean was 2.17%, median was -1.11%
# MODEL svc
# For equalAlpha1Year, yCutoff = 0.01, taken used - 597 is 5.66%
# Mean was -0.1%, median was -6.49%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 2.46%, median was -1.81%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 3.25%, median was -1.56%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 3.38%, median was -1.51%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 0.2%, median was -6.86%
# -----------------
# -----------------
# % of True in dataset 43.75% resulted in 25.62% and median 17.75%
# MODEL tree
# For equalAlpha1Year, yCutoff = 0.02, taken used - 4473 is 42.370000000000005%
# Mean was 3.16%, median was -0.76%
# MODEL svc
# For equalAlpha1Year, yCutoff = 0.02, taken used - 308 is 2.92%
# Mean was 1.29%, median was -4.64%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 2.56%, median was -1.51%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 3.2%, median was -1.28%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 3.04%, median was -1.48%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was -0.12%, median was -6.48%
# -----------------
# -----------------
# % of True in dataset 42.12% resulted in 26.51% and median 18.58%
# MODEL tree
# For equalAlpha1Year, yCutoff = 0.03, taken used - 4275 is 40.5%
# Mean was 3.09%, median was -0.52%
# MODEL svc
# For equalAlpha1Year, yCutoff = 0.03, taken used - 214 is 2.03%
# Mean was 2.38%, median was -0.55%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 2.59%, median was -1.54%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 3.46%, median was -1.18%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 3.11%, median was -1.34%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was -0.57%, median was -5.56%
# -----------------
# -----------------
# % of True in dataset 38.8% resulted in 28.43% and median 20.38%
# MODEL tree
# For equalAlpha1Year, yCutoff = 0.05, taken used - 3996 is 37.86%
# Mean was 3.66%, median was -0.57%
# MODEL svc
# For equalAlpha1Year, yCutoff = 0.05, taken used - 58 is 0.5499999999999999%
# Mean was 7.08%, median was -8.29%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 2.86%, median was -1.3%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 3.65%, median was -0.65%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 3.06%, median was -1.64%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 1.49%, median was -5.53%
# -----------------
# -----------------
# % of True in dataset 35.77% resulted in 30.34% and median 22.22%
# MODEL tree
# For equalAlpha1Year, yCutoff = 0.07, taken used - 3834 is 36.32%
# Mean was 4.05%, median was -0.38%
# MODEL svc
# For equalAlpha1Year, yCutoff = 0.07, taken used - 22 is 0.21%
# Mean was -7.23%, median was -22.78%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 3.38%, median was -0.96%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 3.75%, median was -0.2%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 3.86%, median was -0.44%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 1.89%, median was -2.57%
# -----------------
# -----------------
# % of True in dataset 31.37% resulted in 33.42% and median 24.96%
# MODEL tree
# For equalAlpha1Year, yCutoff = 0.1, taken used - 3279 is 31.06%
# Mean was 3.93%, median was -0.76%
# MODEL svc
# For equalAlpha1Year, yCutoff = 0.1, taken used - 7 is 0.06999999999999999%
# Mean was 15.09%, median was 4.54%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 3.66%, median was -0.13%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 4.08%, median was -0.03%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 3.41%, median was -0.62%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 1.14%, median was -1.8%
# -----------------
# -----------------
# % of True in dataset 25.03% resulted in 38.74% and median 29.39%
# MODEL tree
# For equalAlpha1Year, yCutoff = 0.15, taken used - 2626 is 24.88%
# Mean was 3.71%, median was -0.18%
# MODEL svc
# For equalAlpha1Year, yCutoff = 0.15, taken used - 3 is 0.03%
# Mean was 65.62%, median was 86.77%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 4.61%, median was 0.96%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 5.02%, median was 1.37%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 4.99%, median was 1.37%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 4.83%, median was 1.57%
# -----------------
# -----------------
# % of True in dataset 19.71% resulted in 44.5% and median 34.72%
# MODEL tree
# For equalAlpha1Year, yCutoff = 0.2, taken used - 2231 is 21.13%
# Mean was 5.82%, median was 0.87%
# MODEL svc
# For equalAlpha1Year, yCutoff = 0.2, taken used - 4 is 0.04%
# Mean was 47.42%, median was 51.08%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 4.7%, median was 1.09%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 5.01%, median was 1.46%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 5.16%, median was 1.85%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 7.76%, median was 3.3%
# -----------------
# -----------------
# % of True in dataset 15.63% resulted in 50.24% and median 39.38%
# MODEL tree
# For equalAlpha1Year, yCutoff = 0.25, taken used - 1917 is 18.16%
# Mean was 3.35%, median was -0.67%
# MODEL svc
# For equalAlpha1Year, yCutoff = 0.25, taken used - 2 is 0.02%
# Mean was 51.08%, median was 51.08%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 4.7%, median was 1.21%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 5.5%, median was 1.84%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 6.63%, median was 3.44%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 7.11%, median was 4.06%
# -----------------
# -----------------
# % of True in dataset 9.77% resulted in 62.75% and median 50.03%
# MODEL tree
# For equalAlpha1Year, yCutoff = 0.35, taken used - 1376 is 13.04%
# Mean was 5.46%, median was 0.8%
# MODEL svc
# For equalAlpha1Year, yCutoff = 0.35, taken used - 0 is 0.0%
# Mean was nan%, median was nan%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 4.76%, median was 1.55%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 6.02%, median was 2.66%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 6.85%, median was 3.98%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 7.71%, median was 4.46%
# -----------------
# -----------------
# % of True in dataset 47.39% resulted in 23.85% and median 16.33%
# MODEL tree
# For equalAdjustedAlpha1Year, yCutoff = 0.0, taken used - 4507 is 42.699999999999996%
# Mean was 2.58%, median was -1.03%
# MODEL svc
# For equalAdjustedAlpha1Year, yCutoff = 0.0, taken used - 789 is 7.470000000000001%
# Mean was 3.26%, median was -0.46%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 2.84%, median was -0.87%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 3.31%, median was -1.07%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 3.92%, median was -1.05%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 4.89%, median was -0.44%
# -----------------
# -----------------
# % of True in dataset 45.76% resulted in 24.69% and median 17.04%
# MODEL tree
# For equalAdjustedAlpha1Year, yCutoff = 0.01, taken used - 4565 is 43.25%
# Mean was 3.3%, median was -0.21%
# MODEL svc
# For equalAdjustedAlpha1Year, yCutoff = 0.01, taken used - 450 is 4.26%
# Mean was 5.32%, median was 0.38%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 2.72%, median was -1.11%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 3.08%, median was -1.39%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 3.13%, median was -1.28%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 4.92%, median was -0.14%
# -----------------
# -----------------
# % of True in dataset 44.09% resulted in 25.57% and median 17.74%
# MODEL tree
# For equalAdjustedAlpha1Year, yCutoff = 0.02, taken used - 4053 is 38.4%
# Mean was 2.46%, median was -0.51%
# MODEL svc
# For equalAdjustedAlpha1Year, yCutoff = 0.02, taken used - 256 is 2.4299999999999997%
# Mean was 4.61%, median was 1.65%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 2.93%, median was -0.61%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 3.31%, median was -0.51%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 3.86%, median was -0.42%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 5.05%, median was 0.85%
# -----------------
# -----------------
# % of True in dataset 42.43% resulted in 26.47% and median 18.63%
# MODEL tree
# For equalAdjustedAlpha1Year, yCutoff = 0.03, taken used - 4374 is 41.44%
# Mean was 3.55%, median was 0.16%
# MODEL svc
# For equalAdjustedAlpha1Year, yCutoff = 0.03, taken used - 147 is 1.39%
# Mean was 4.31%, median was 1.02%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 3.16%, median was -0.54%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 3.58%, median was -0.51%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 3.76%, median was -0.48%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 5.02%, median was 1.01%
# -----------------
# -----------------
# % of True in dataset 39.25% resulted in 28.29% and median 20.26%
# MODEL tree
# For equalAdjustedAlpha1Year, yCutoff = 0.05, taken used - 3915 is 37.09%
# Mean was 3.3%, median was -0.23%
# MODEL svc
# For equalAdjustedAlpha1Year, yCutoff = 0.05, taken used - 71 is 0.67%
# Mean was -1.32%, median was -9.25%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 3.17%, median was -0.46%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 3.62%, median was -0.42%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 4.69%, median was -0.05%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 3.11%, median was 0.94%
# -----------------
# -----------------
# % of True in dataset 35.92% resulted in 30.35% and median 22.18%
# MODEL tree
# For equalAdjustedAlpha1Year, yCutoff = 0.07, taken used - 3744 is 35.47%
# Mean was 3.81%, median was -0.57%
# MODEL svc
# For equalAdjustedAlpha1Year, yCutoff = 0.07, taken used - 26 is 0.25%
# Mean was -5.06%, median was -14.31%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 3.43%, median was -0.12%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 3.87%, median was -0.02%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 5.71%, median was 0.58%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 4.61%, median was 1.03%
# -----------------
# -----------------
# % of True in dataset 31.63% resulted in 33.32% and median 24.9%
# MODEL tree
# For equalAdjustedAlpha1Year, yCutoff = 0.1, taken used - 3262 is 30.9%
# Mean was 3.95%, median was -0.59%
# MODEL svc
# For equalAdjustedAlpha1Year, yCutoff = 0.1, taken used - 7 is 0.06999999999999999%
# Mean was 13.06%, median was 2.42%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 3.65%, median was 0.05%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 4.28%, median was 0.66%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 5.55%, median was 0.85%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 4.73%, median was 1.24%
# -----------------
# -----------------
# % of True in dataset 25.26% resulted in 38.59% and median 29.13%
# MODEL tree
# For equalAdjustedAlpha1Year, yCutoff = 0.15, taken used - 2751 is 26.06%
# Mean was 2.16%, median was -1.79%
# MODEL svc
# For equalAdjustedAlpha1Year, yCutoff = 0.15, taken used - 3 is 0.03%
# Mean was 63.51%, median was 84.72%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 4.4%, median was 1.09%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 5.84%, median was 1.93%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 6.5%, median was 2.49%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 6.63%, median was 3.77%
# -----------------
# -----------------
# % of True in dataset 19.92% resulted in 44.28% and median 34.6%
# MODEL tree
# For equalAdjustedAlpha1Year, yCutoff = 0.2, taken used - 2277 is 21.57%
# Mean was 3.58%, median was -0.46%
# MODEL svc
# For equalAdjustedAlpha1Year, yCutoff = 0.2, taken used - 3 is 0.03%
# Mean was 63.51%, median was 84.72%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 4.83%, median was 1.67%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 5.66%, median was 1.93%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 6.62%, median was 2.56%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 6.98%, median was 3.61%
# -----------------
# -----------------
# % of True in dataset 15.77% resulted in 50.03% and median 39.08%
# MODEL tree
# For equalAdjustedAlpha1Year, yCutoff = 0.25, taken used - 1824 is 17.28%
# Mean was 4.99%, median was 0.27%
# MODEL svc
# For equalAdjustedAlpha1Year, yCutoff = 0.25, taken used - 2 is 0.02%
# Mean was 48.97%, median was 48.97%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 4.76%, median was 1.77%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 5.28%, median was 1.99%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 6.43%, median was 3.25%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 7.79%, median was 4.2%
# -----------------
# -----------------
# % of True in dataset 9.75% resulted in 62.83% and median 49.82%
# MODEL tree
# For equalAdjustedAlpha1Year, yCutoff = 0.35, taken used - 1335 is 12.65%
# Mean was 7.06%, median was 1.07%
# MODEL svc
# For equalAdjustedAlpha1Year, yCutoff = 0.35, taken used - 0 is 0.0%
# Mean was nan%, median was nan%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 4.84%, median was 1.82%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 6.03%, median was 3.07%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 7.72%, median was 4.62%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 8.4%, median was 5.48%
# -----------------
# -----------------
# % of True in dataset 41.89% resulted in 48.06% and median 27.21%
# MODEL tree
# For alpha2Year, yCutoff = 0.0, taken used - 5167 is 48.949999999999996%
# Mean was 3.98%, median was -5.5%
# MODEL svc
# For alpha2Year, yCutoff = 0.0, taken used - 3829 is 36.27%
# Mean was 12.68%, median was -0.89%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 14.78%, median was -0.27%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 16.92%, median was 1.26%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 23.4%, median was 2.4%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 34.54%, median was 3.22%
# -----------------
# -----------------
# % of True in dataset 40.8% resulted in 49.33% and median 28.66%
# MODEL tree
# For alpha2Year, yCutoff = 0.01, taken used - 4780 is 45.28%
# Mean was 7.01%, median was -2.75%
# MODEL svc
# For alpha2Year, yCutoff = 0.01, taken used - 3070 is 29.080000000000002%
# Mean was 15.44%, median was -0.27%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 14.99%, median was -0.38%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 16.94%, median was 1.24%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 24.09%, median was 2.29%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 35.81%, median was 2.81%
# -----------------
# -----------------
# % of True in dataset 39.75% resulted in 50.6% and median 29.61%
# MODEL tree
# For alpha2Year, yCutoff = 0.02, taken used - 4672 is 44.26%
# Mean was 5.26%, median was -4.67%
# MODEL svc
# For alpha2Year, yCutoff = 0.02, taken used - 2534 is 24.01%
# Mean was 16.51%, median was 1.46%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 15.14%, median was -0.27%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 17.07%, median was 1.3%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 24.05%, median was 1.39%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 37.57%, median was 3.85%
# -----------------
# -----------------
# % of True in dataset 38.76% resulted in 51.82% and median 30.41%
# MODEL tree
# For alpha2Year, yCutoff = 0.03, taken used - 4625 is 43.81%
# Mean was 7.92%, median was -2.71%
# MODEL svc
# For alpha2Year, yCutoff = 0.03, taken used - 1770 is 16.77%
# Mean was 18.67%, median was 1.44%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 15.35%, median was -0.1%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 17.05%, median was 0.42%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 23.88%, median was 1.39%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 37.42%, median was 3.85%
# -----------------
# -----------------
# % of True in dataset 36.78% resulted in 54.4% and median 32.54%
# MODEL tree
# For alpha2Year, yCutoff = 0.05, taken used - 4391 is 41.6%
# Mean was 8.41%, median was -2.16%
# MODEL svc
# For alpha2Year, yCutoff = 0.05, taken used - 876 is 8.3%
# Mean was 26.77%, median was 2.45%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 15.01%, median was -0.27%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 17.13%, median was 0.44%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 23.69%, median was 1.24%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 37.47%, median was 3.43%
# -----------------
# -----------------
# % of True in dataset 35.02% resulted in 56.83% and median 34.23%
# MODEL tree
# For alpha2Year, yCutoff = 0.07, taken used - 4173 is 39.53%
# Mean was 9.04%, median was -1.2%
# MODEL svc
# For alpha2Year, yCutoff = 0.07, taken used - 349 is 3.3099999999999996%
# Mean was 44.29%, median was 10.08%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 14.18%, median was -0.54%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 17.3%, median was 0.36%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 24.1%, median was 0.98%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 37.5%, median was 3.85%
# -----------------
# -----------------
# % of True in dataset 32.51% resulted in 60.56% and median 37.46%
# MODEL tree
# For alpha2Year, yCutoff = 0.1, taken used - 3926 is 37.19%
# Mean was 11.12%, median was -0.63%
# MODEL svc
# For alpha2Year, yCutoff = 0.1, taken used - 116 is 1.0999999999999999%
# Mean was 53.86%, median was 7.76%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 13.07%, median was -0.9%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 17.48%, median was 0.06%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 23.14%, median was 0.98%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 31.63%, median was 3.22%
# -----------------
# -----------------
# % of True in dataset 28.72% resulted in 66.91% and median 42.86%
# MODEL tree
# For alpha2Year, yCutoff = 0.15, taken used - 3533 is 33.47%
# Mean was 7.12%, median was -2.47%
# MODEL svc
# For alpha2Year, yCutoff = 0.15, taken used - 8 is 0.08%
# Mean was 94.52%, median was 5.05%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 12.53%, median was -1.5%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 16.06%, median was -0.45%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 23.44%, median was 1.61%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 30.52%, median was 2.66%
# -----------------
# -----------------
# % of True in dataset 25.33% resulted in 73.53% and median 48.83%
# MODEL tree
# For alpha2Year, yCutoff = 0.2, taken used - 2937 is 27.82%
# Mean was 8.94%, median was -0.88%
# MODEL svc
# For alpha2Year, yCutoff = 0.2, taken used - 3 is 0.03%
# Mean was -28.9%, median was -27.54%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 12.27%, median was -1.65%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 16.18%, median was -0.81%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 21.28%, median was 0.72%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 30.95%, median was 2.66%
# -----------------
# -----------------
# % of True in dataset 22.27% resulted in 80.55% and median 53.52%
# MODEL tree
# For alpha2Year, yCutoff = 0.25, taken used - 2748 is 26.029999999999998%
# Mean was 15.23%, median was 0.42%
# MODEL svc
# For alpha2Year, yCutoff = 0.25, taken used - 0 is 0.0%
# Mean was nan%, median was nan%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 12.26%, median was -1.5%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 16.98%, median was -0.28%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 21.23%, median was 0.38%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 29.59%, median was 0.67%
# -----------------
# -----------------
# % of True in dataset 17.19% resulted in 95.53% and median 64.82%
# MODEL tree
# For alpha2Year, yCutoff = 0.35, taken used - 2153 is 20.4%
# Mean was 19.9%, median was 4.05%
# MODEL svc
# For alpha2Year, yCutoff = 0.35, taken used - 0 is 0.0%
# Mean was nan%, median was nan%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 11.9%, median was -1.78%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 15.56%, median was -1.39%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 21.32%, median was -0.01%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 33.27%, median was 3.86%
# -----------------
# -----------------
# % of True in dataset 42.47% resulted in 47.95% and median 26.96%
# MODEL tree
# For adjustedAlpha2Year, yCutoff = 0.0, taken used - 5081 is 48.13%
# Mean was 5.61%, median was -4.04%
# MODEL svc
# For adjustedAlpha2Year, yCutoff = 0.0, taken used - 3622 is 34.31%
# Mean was 13.05%, median was -0.71%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 13.8%, median was -0.34%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 15.39%, median was -0.46%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 23.67%, median was 1.9%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 39.26%, median was 7.24%
# -----------------
# -----------------
# % of True in dataset 41.31% resulted in 49.28% and median 28.15%
# MODEL tree
# For adjustedAlpha2Year, yCutoff = 0.01, taken used - 4904 is 46.46%
# Mean was 7.59%, median was -2.87%
# MODEL svc
# For adjustedAlpha2Year, yCutoff = 0.01, taken used - 2938 is 27.83%
# Mean was 14.48%, median was 0.28%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 14.36%, median was -0.06%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 16.04%, median was 0.22%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 24.16%, median was 2.01%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 38.88%, median was 6.39%
# -----------------
# -----------------
# % of True in dataset 40.37% resulted in 50.4% and median 28.96%
# MODEL tree
# For adjustedAlpha2Year, yCutoff = 0.02, taken used - 4850 is 45.95%
# Mean was 7.81%, median was -3.74%
# MODEL svc
# For adjustedAlpha2Year, yCutoff = 0.02, taken used - 2194 is 20.78%
# Mean was 16.2%, median was 0.22%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 14.42%, median was 0.05%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 16.44%, median was 0.28%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 22.78%, median was 0.79%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 38.1%, median was 4.61%
# -----------------
# -----------------
# % of True in dataset 39.24% resulted in 51.78% and median 30.29%
# MODEL tree
# For adjustedAlpha2Year, yCutoff = 0.03, taken used - 4792 is 45.4%
# Mean was 4.09%, median was -4.78%
# MODEL svc
# For adjustedAlpha2Year, yCutoff = 0.03, taken used - 1665 is 15.770000000000001%
# Mean was 17.48%, median was -0.47%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 14.79%, median was 0.14%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 16.94%, median was 0.32%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 23.97%, median was 1.62%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 39.0%, median was 4.85%
# -----------------
# -----------------
# % of True in dataset 37.43% resulted in 54.09% and median 31.95%
# MODEL tree
# For adjustedAlpha2Year, yCutoff = 0.05, taken used - 4529 is 42.9%
# Mean was 6.14%, median was -3.07%
# MODEL svc
# For adjustedAlpha2Year, yCutoff = 0.05, taken used - 941 is 8.91%
# Mean was 23.5%, median was 0.28%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 12.57%, median was -0.97%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 16.07%, median was 0.13%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 24.37%, median was 0.79%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 33.61%, median was 3.83%
# -----------------
# -----------------
# % of True in dataset 35.67% resulted in 56.47% and median 34.2%
# MODEL tree
# For adjustedAlpha2Year, yCutoff = 0.07, taken used - 4365 is 41.349999999999994%
# Mean was 6.23%, median was -2.02%
# MODEL svc
# For adjustedAlpha2Year, yCutoff = 0.07, taken used - 346 is 3.2800000000000002%
# Mean was 43.59%, median was 6.71%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 12.88%, median was -0.95%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 16.01%, median was 0.05%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 23.48%, median was 0.51%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 28.9%, median was 3.07%
# -----------------
# -----------------
# % of True in dataset 33.14% resulted in 60.13% and median 37.33%
# MODEL tree
# For adjustedAlpha2Year, yCutoff = 0.1, taken used - 4016 is 38.04%
# Mean was 9.05%, median was -2.92%
# MODEL svc
# For adjustedAlpha2Year, yCutoff = 0.1, taken used - 74 is 0.7000000000000001%
# Mean was 32.24%, median was -4.04%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 12.78%, median was -0.5%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 15.99%, median was 0.06%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 22.61%, median was 0.28%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 28.71%, median was 1.56%
# -----------------
# -----------------
# % of True in dataset 29.19% resulted in 66.58% and median 42.76%
# MODEL tree
# For adjustedAlpha2Year, yCutoff = 0.15, taken used - 3556 is 33.69%
# Mean was 8.73%, median was -1.39%
# MODEL svc
# For adjustedAlpha2Year, yCutoff = 0.15, taken used - 14 is 0.13%
# Mean was -6.91%, median was -16.9%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 12.08%, median was -1.5%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 15.71%, median was -0.21%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 21.0%, median was 0.21%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 29.28%, median was 2.8%
# -----------------
# -----------------
# % of True in dataset 25.56% resulted in 73.56% and median 48.56%
# MODEL tree
# For adjustedAlpha2Year, yCutoff = 0.2, taken used - 3117 is 29.53%
# Mean was 8.28%, median was -2.83%
# MODEL svc
# For adjustedAlpha2Year, yCutoff = 0.2, taken used - 3 is 0.03%
# Mean was -32.35%, median was -30.96%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 12.41%, median was -1.1%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 15.13%, median was -0.98%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 21.14%, median was -0.58%
# % of True taken with threshold 95 adjustment -  528
# ...
# Mean was 9.94%, median was -2.88%
# MODEL svc
# For equalAlpha2Year, yCutoff = 0.01, taken used - 6329 is 59.96%
# Mean was 10.43%, median was -2.35%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 17.19%, median was 1.25%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 21.35%, median was 2.48%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 35.44%, median was 7.1%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 47.34%, median was 8.11%
# -----------------
# -----------------
# % of True in dataset 40.17% resulted in 51.26% and median 29.83%
# MODEL tree
# For equalAlpha2Year, yCutoff = 0.02, taken used - 4287 is 40.61%
# Mean was 10.24%, median was -2.7%
# MODEL svc
# For equalAlpha2Year, yCutoff = 0.02, taken used - 6283 is 59.519999999999996%
# Mean was 10.3%, median was -2.51%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 16.88%, median was 0.94%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 21.0%, median was 1.46%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 34.63%, median was 6.12%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 48.72%, median was 8.88%
# -----------------
# -----------------
# % of True in dataset 39.15% resulted in 52.52% and median 30.94%
# MODEL tree
# For equalAlpha2Year, yCutoff = 0.03, taken used - 3815 is 36.14%
# Mean was 11.06%, median was -2.73%
# MODEL svc
# For equalAlpha2Year, yCutoff = 0.03, taken used - 6312 is 59.8%
# Mean was 10.34%, median was -2.45%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 16.98%, median was 0.77%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 21.14%, median was 1.55%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 33.86%, median was 5.65%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 48.75%, median was 8.88%
# -----------------
# -----------------
# % of True in dataset 37.4% resulted in 54.79% and median 32.85%
# MODEL tree
# For equalAlpha2Year, yCutoff = 0.05, taken used - 3459 is 32.769999999999996%
# Mean was 11.88%, median was 0.9%
# MODEL svc
# For equalAlpha2Year, yCutoff = 0.05, taken used - 6397 is 60.6%
# Mean was 10.23%, median was -2.39%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 16.51%, median was 0.42%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 21.29%, median was 2.15%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 33.19%, median was 5.15%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 49.49%, median was 9.23%
# -----------------
# -----------------
# % of True in dataset 35.72% resulted in 57.08% and median 34.74%
# MODEL tree
# For equalAlpha2Year, yCutoff = 0.07, taken used - 3306 is 31.319999999999997%
# Mean was 11.27%, median was -1.57%
# MODEL svc
# For equalAlpha2Year, yCutoff = 0.07, taken used - 6267 is 59.37%
# Mean was 10.25%, median was -2.46%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 15.89%, median was -0.15%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 21.06%, median was 1.9%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 31.4%, median was 4.0%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 46.81%, median was 8.46%
# -----------------
# -----------------
# % of True in dataset 33.02% resulted in 61.06% and median 38.33%
# MODEL tree
# For equalAlpha2Year, yCutoff = 0.1, taken used - 3222 is 30.520000000000003%
# Mean was 15.22%, median was 0.95%
# MODEL svc
# For equalAlpha2Year, yCutoff = 0.1, taken used - 6228 is 59.0%
# Mean was 10.02%, median was -2.78%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 15.72%, median was -0.44%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 20.91%, median was 1.17%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 31.21%, median was 4.9%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 46.73%, median was 7.72%
# -----------------
# -----------------
# % of True in dataset 28.99% resulted in 67.83% and median 44.19%
# MODEL tree
# For equalAlpha2Year, yCutoff = 0.15, taken used - 2830 is 26.810000000000002%
# Mean was 11.56%, median was -0.96%
# MODEL svc
# For equalAlpha2Year, yCutoff = 0.15, taken used - 6191 is 58.650000000000006%
# Mean was 10.08%, median was -2.52%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 15.53%, median was -0.21%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 20.51%, median was 1.0%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 31.05%, median was 4.82%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 42.44%, median was 7.86%
# -----------------
# -----------------
# % of True in dataset 25.71% resulted in 74.25% and median 49.49%
# MODEL tree
# For equalAlpha2Year, yCutoff = 0.2, taken used - 2297 is 21.759999999999998%
# Mean was 13.43%, median was -0.19%
# MODEL svc
# For equalAlpha2Year, yCutoff = 0.2, taken used - 6182 is 58.56%
# Mean was 10.1%, median was -2.45%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 15.42%, median was -0.08%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 20.52%, median was 0.88%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 31.82%, median was 4.0%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 42.94%, median was 9.23%
# -----------------
# -----------------
# % of True in dataset 22.6% resulted in 81.39% and median 55.15%
# MODEL tree
# For equalAlpha2Year, yCutoff = 0.25, taken used - 2235 is 21.17%
# Mean was 10.41%, median was 0.31%
# MODEL svc
# For equalAlpha2Year, yCutoff = 0.25, taken used - 6106 is 57.84%
# Mean was 10.22%, median was -2.45%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 15.59%, median was 0.18%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 20.05%, median was 0.95%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 28.37%, median was 2.48%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 40.17%, median was 9.95%
# -----------------
# -----------------
# % of True in dataset 17.77% resulted in 95.42% and median 64.23%
# MODEL tree
# For equalAlpha2Year, yCutoff = 0.35, taken used - 1489 is 14.11%
# Mean was 19.24%, median was -1.12%
# MODEL svc
# For equalAlpha2Year, yCutoff = 0.35, taken used - 6083 is 57.63%
# Mean was 9.69%, median was -2.48%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 15.05%, median was -0.5%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 18.76%, median was -0.59%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 27.48%, median was 2.18%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 39.68%, median was 9.81%
# -----------------
# -----------------
# % of True in dataset 42.21% resulted in 48.83% and median 27.84%
# MODEL tree
# For equalAdjustedAlpha2Year, yCutoff = 0.0, taken used - 4066 is 38.519999999999996%
# Mean was 11.14%, median was -1.09%
# MODEL svc
# For equalAdjustedAlpha2Year, yCutoff = 0.0, taken used - 5936 is 56.230000000000004%
# Mean was 10.36%, median was -2.36%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 15.55%, median was 0.31%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 21.62%, median was 2.96%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 32.69%, median was 8.31%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 50.8%, median was 13.56%
# -----------------
# -----------------
# % of True in dataset 41.28% resulted in 49.93% and median 28.73%
# MODEL tree
# For equalAdjustedAlpha2Year, yCutoff = 0.01, taken used - 4000 is 37.89%
# Mean was 11.83%, median was -0.7%
# MODEL svc
# For equalAdjustedAlpha2Year, yCutoff = 0.01, taken used - 5949 is 56.36%
# Mean was 10.28%, median was -2.47%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 15.72%, median was 0.31%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 21.7%, median was 2.96%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 32.67%, median was 7.41%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 51.32%, median was 13.56%
# -----------------
# -----------------
# % of True in dataset 40.38% resulted in 51.0% and median 29.72%
# MODEL tree
# For equalAdjustedAlpha2Year, yCutoff = 0.02, taken used - 3894 is 36.89%
# Mean was 12.46%, median was -1.59%
# MODEL svc
# For equalAdjustedAlpha2Year, yCutoff = 0.02, taken used - 6026 is 57.089999999999996%
# Mean was 9.99%, median was -2.63%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 15.87%, median was 0.23%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 21.01%, median was 2.55%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 32.84%, median was 6.91%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 52.12%, median was 14.2%
# -----------------
# -----------------
# % of True in dataset 39.26% resulted in 52.39% and median 31.04%
# MODEL tree
# For equalAdjustedAlpha2Year, yCutoff = 0.03, taken used - 3726 is 35.3%
# Mean was 12.4%, median was -0.21%
# MODEL svc
# For equalAdjustedAlpha2Year, yCutoff = 0.03, taken used - 6052 is 57.330000000000005%
# Mean was 9.99%, median was -2.63%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 15.71%, median was 0.23%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 20.96%, median was 1.98%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 33.39%, median was 7.2%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 51.38%, median was 13.25%
# -----------------
# -----------------
# % of True in dataset 37.48% resulted in 54.7% and median 32.89%
# MODEL tree
# For equalAdjustedAlpha2Year, yCutoff = 0.05, taken used - 3662 is 34.69%
# Mean was 12.28%, median was -1.67%
# MODEL svc
# For equalAdjustedAlpha2Year, yCutoff = 0.05, taken used - 6046 is 57.28%
# Mean was 9.85%, median was -2.72%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 15.3%, median was 0.05%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 20.07%, median was 1.43%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 32.61%, median was 5.91%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 50.01%, median was 12.43%
# -----------------
# -----------------
# % of True in dataset 35.64% resulted in 57.21% and median 34.98%
# MODEL tree
# For equalAdjustedAlpha2Year, yCutoff = 0.07, taken used - 3270 is 30.98%
# Mean was 12.66%, median was -1.66%
# MODEL svc
# For equalAdjustedAlpha2Year, yCutoff = 0.07, taken used - 6029 is 57.11000000000001%
# Mean was 9.57%, median was -2.95%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 15.59%, median was 0.05%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 20.53%, median was 1.27%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 32.46%, median was 5.91%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 45.98%, median was 10.18%
# -----------------
# -----------------
# % of True in dataset 32.98% resulted in 61.13% and median 38.12%
# MODEL tree
# For equalAdjustedAlpha2Year, yCutoff = 0.1, taken used - 3144 is 29.78%
# Mean was 9.71%, median was -1.84%
# MODEL svc
# For equalAdjustedAlpha2Year, yCutoff = 0.1, taken used - 6066 is 57.46%
# Mean was 9.94%, median was -2.51%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 14.97%, median was -0.2%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 19.57%, median was 1.18%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 33.66%, median was 8.1%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 46.73%, median was 12.43%
# -----------------
# -----------------
# % of True in dataset 29.07% resulted in 67.69% and median 43.88%
# MODEL tree
# For equalAdjustedAlpha2Year, yCutoff = 0.15, taken used - 2732 is 25.88%
# Mean was 13.31%, median was -1.74%
# MODEL svc
# For equalAdjustedAlpha2Year, yCutoff = 0.15, taken used - 6028 is 57.099999999999994%
# Mean was 9.45%, median was -2.72%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 15.25%, median was 0.23%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 20.1%, median was 1.36%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 32.19%, median was 6.02%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 43.41%, median was 11.47%
# -----------------
# -----------------
# % of True in dataset 25.45% resulted in 74.85% and median 49.32%
# MODEL tree
# For equalAdjustedAlpha2Year, yCutoff = 0.2, taken used - 2409 is 22.82%
# Mean was 11.93%, median was -2.9%
# MODEL svc
# For equalAdjustedAlpha2Year, yCutoff = 0.2, taken used - 5979 is 56.64%
# Mean was 9.71%, median was -2.43%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 15.36%, median was 0.58%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 19.41%, median was 0.84%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 30.96%, median was 5.32%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 39.44%, median was 9.44%
# -----------------
# -----------------
# % of True in dataset 22.57% resulted in 81.56% and median 54.38%
# MODEL tree
# For equalAdjustedAlpha2Year, yCutoff = 0.25, taken used - 2057 is 19.49%
# Mean was 13.36%, median was 0.75%
# MODEL svc
# For equalAdjustedAlpha2Year, yCutoff = 0.25, taken used - 5887 is 55.769999999999996%
# Mean was 9.71%, median was -2.63%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 15.17%, median was 0.05%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 19.36%, median was 0.94%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 30.09%, median was 4.12%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 40.08%, median was 10.86%
# -----------------
# -----------------
# % of True in dataset 17.8% resulted in 95.44% and median 64.29%
# MODEL tree
# For equalAdjustedAlpha2Year, yCutoff = 0.35, taken used - 1652 is 15.65%
# Mean was 16.15%, median was 0.15%
# MODEL svc
# For equalAdjustedAlpha2Year, yCutoff = 0.35, taken used - 5864 is 55.55%
# Mean was 8.88%, median was -2.68%
# % of True taken with threshold 70 adjustment -  3167
# For threshold data - mean was 13.3%, median was -1.61%
# % of True taken with threshold 80 adjustment -  2112
# For threshold data - mean was 17.7%, median was -0.62%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 23.03%, median was -0.23%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 35.67%, median was 4.05%
# -----------------

# %%
with open('./results-deduplicated/finalPlot-year.json', 'w') as f:
    json.dump(resultsToPlotYear, f, default=float)
with open('./results-deduplicated/finalPlotBalanced-year.json', 'w') as f:
    json.dump(balancedResultsYear, f, default=float)
# with open('./results-deduplicated/finalPlot-company.json', 'w') as f:
#     json.dump(resultsToPlotCompany, f, default=float)
# with open('./results-deduplicated/finalPlotBalanced-company.json', 'w') as f:
#     json.dump(balancedResultsCompany, f, default=float)
# with open('./results-deduplicated/finalPlot-rand.json', 'w') as f:
#     json.dump(resultsToPlotRand, f, default=float)
# with open('./results-deduplicated/finalPlotBalanced-rand.json', 'w') as f:
#     json.dump(balancedResultsRand, f, default=float)

# %%
with open('./results-deduplicated/finalPlot-year.json', 'r') as f:
    resultsToPlotYear = json.load(f)
with open('./results-deduplicated/finalPlotBalanced-year.json', 'r') as f:
    balancedResultsYear = json.load(f)
# with open('./results-deduplicated/finalPlot-company.json', 'r') as f:
#     resultsToPlotCompany = json.load(f)
# with open('./results-deduplicated/finalPlotBalanced-company.json', 'r') as f:
#     balancedResultsCompany = json.load(f)
# with open('./results-deduplicated/finalPlot-rand.json', 'r') as f:
#     resultsToPlotRand = json.load(f)
# with open('./results-deduplicated/finalPlotBalanced-rand.json', 'r') as f:
#     balancedResultsRand = json.load(f)

# %% [markdown]
# resultsToPlotYear AND balancedResultsYear

# %%
for yLabel in resultsToPlotYear.keys():
    thresholdKeys = [f'svcThreshold{threshold}' for threshold in thresholds]
    toPlot = resultsToPlotYear[yLabel]

    drawFrom1results(resultsToPlotYear[yLabel], yLabel, cutoffs, title='No Weights', keys=['svc', 'tree', *thresholdKeys])
    plt.show()

    drawFrom1results(balancedResultsYear[yLabel], yLabel, cutoffs, title='Balanced', keys=['svc', 'tree', *thresholdKeys])
    plt.show()

# %% [markdown]
# resultsToPlotCompany AND balancedResultsCompany

# %%
# for yLabel in resultsToPlotCompany.keys():
#     thresholdKeys = [f'svcThreshold{threshold}' for threshold in thresholds]
#     toPlot = resultsToPlotCompany[yLabel]
#
#     drawFrom1results(resultsToPlotCompany[yLabel], yLabel, cutoffs, title='No Weights', keys=['svc', 'tree', *thresholdKeys])
#     plt.show()
#
#     drawFrom1results(balancedResultsCompany[yLabel], yLabel, cutoffs, title='Balanced', keys=['svc', 'tree', *thresholdKeys])
#     plt.show()

# %% [markdown]
# resultsToPlotRand AND balancedResultsRand

# %%
# for yLabel in resultsToPlotRand.keys():
#     thresholdKeys = [f'svcThreshold{threshold}' for threshold in thresholds]
#     toPlot = resultsToPlotRand[yLabel]
#
#     drawFrom1results(resultsToPlotRand[yLabel], yLabel, cutoffs, title='No Weights', keys=['svc', 'tree', *thresholdKeys])
#     plt.show()
#
#     drawFrom1results(balancedResultsRand[yLabel], yLabel, cutoffs, title='Balanced', keys=['svc', 'tree', *thresholdKeys])
#     plt.show()
