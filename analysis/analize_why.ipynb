# %%
import pandas as pd

from headers import *
from training_helper import trainPipeline
from utils.custom_train_test_split import *
from joblib import dump, load
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from numpy import mean

# %%
cutoffs = [0.10, 0.15, 0.20]
files = ['../data/deduplicated/combined_inner_ticker.csv']
thresholds = [90, 95]
# yLabels = ['alpha1Year', 'alpha2Year']
yLabels = ['alpha1Year']
modelKeys = ['svc', 'tree']

# %%
trainDf, testDf = per_year_train_test_split(files, format='%Y-%m-%d')
X_train = trainDf[ratioKeys + relativeRatioKeys]
X_test = testDf[ratioKeys + relativeRatioKeys]

# %%
cutoffs = [0.0, 0.10, 0.15, 0.20, 0.35]
modelKeys = ['svc',]
trainPipeline(cutoffs, yLabels, trainDf, testDf, thresholds, saveModel=True, isBalanced=True)
# Out:
# -----------------
# % of True in dataset 50.92% resulted in 24.61% and median 17.28%
# MODEL tree
# For alpha1Year, yCutoff = 0.0, taken used - 4975 is 47.13%
# Mean was 4.92%, median was 1.81%
# MODEL svc
# For alpha1Year, yCutoff = 0.0, taken used - 4810 is 45.57%
# Mean was 4.8%, median was 1.19%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 7.81%, median was 1.38%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 3.48%, median was -2.29%
# -----------------
# -----------------
# % of True in dataset 35.23% resulted in 33.35% and median 25.45%
# MODEL tree
# For alpha1Year, yCutoff = 0.1, taken used - 3475 is 32.92%
# Mean was 6.23%, median was 2.06%
# MODEL svc
# For alpha1Year, yCutoff = 0.1, taken used - 4988 is 47.25%
# Mean was 4.75%, median was 1.31%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 7.15%, median was 0.87%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 6.35%, median was 1.82%
# -----------------
# -----------------
# % of True in dataset 28.24% resulted in 38.53% and median 29.9%
# MODEL tree
# For alpha1Year, yCutoff = 0.15, taken used - 2884 is 27.32%
# Mean was 6.56%, median was 1.27%
# MODEL svc
# For alpha1Year, yCutoff = 0.15, taken used - 4963 is 47.02%
# Mean was 4.92%, median was 1.62%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 7.64%, median was 2.23%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 9.09%, median was 4.39%
# -----------------
# -----------------
# % of True in dataset 22.51% resulted in 43.88% and median 34.47%
# MODEL tree
# For alpha1Year, yCutoff = 0.2, taken used - 2491 is 23.599999999999998%
# Mean was 6.21%, median was 0.84%
# MODEL svc
# For alpha1Year, yCutoff = 0.2, taken used - 4881 is 46.239999999999995%
# Mean was 5.05%, median was 1.77%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 7.29%, median was 2.57%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 8.56%, median was 3.72%
# -----------------
# -----------------
# % of True in dataset 10.94% resulted in 61.91% and median 49.66%
# MODEL tree
# For alpha1Year, yCutoff = 0.35, taken used - 1184 is 11.219999999999999%
# Mean was 9.7%, median was 3.34%
# MODEL svc
# For alpha1Year, yCutoff = 0.35, taken used - 4685 is 44.379999999999995%
# Mean was 5.14%, median was 1.95%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 6.83%, median was 3.48%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 9.7%, median was 5.18%
# -----------------
# {'alpha1Year': {'tree': [{'mean': np.float64(0.04918178930199273),
#     'median': np.float64(0.0181092795664793),
#     'taken': np.int64(4975)},
#    {'mean': np.float64(0.06227801049402202),
#     'median': np.float64(0.0206069183571782),
#     'taken': np.int64(3475)},
#    {'mean': np.float64(0.06557951406604919),
#     'median': np.float64(0.012687612194422049),
#     'taken': np.int64(2884)},
#    {'mean': np.float64(0.06210107925665286),
#     'median': np.float64(0.0084456281149317),
#     'taken': np.int64(2491)},
#    {'mean': np.float64(0.09700395197842221),
#     'median': np.float64(0.03338911586501295),
#     'taken': np.int64(1184)}],
#   'svc': [{'mean': np.float64(0.048025976308212856),
#     'median': np.float64(0.011923310892604299),
#     'taken': np.int64(4810)},
#    {'mean': np.float64(0.04747311462341424),
#     'median': np.float64(0.01314019390909185),
#     'taken': np.int64(4988)},
#    {'mean': np.float64(0.049200691614255075),
#     'median': np.float64(0.0162187919389906),
#     'taken': np.int64(4963)},
#    {'mean': np.float64(0.050528199724309934),
#     'median': np.float64(0.0176522655204212),
#     'taken': np.int64(4881)},
#    {'mean': np.float64(0.05144252654814227),
#     'median': np.float64(0.0195053729369531),
#     'taken': np.int64(4685)}],
#   'svcThreshold90': [{'mean': np.float64(0.0781170458406915),
#     'median': np.float64(0.01377987860833375),
#     'taken': -1},
#    {'mean': np.float64(0.07152652179025626),
#     'median': np.float64(0.008708880775651049),
#     'taken': -1},
#    {'mean': np.float64(0.07640937958990804),
#     'median': np.float64(0.0222926166133985),
#     'taken': -1},
#    {'mean': np.float64(0.07290462685363955),
#     'median': np.float64(0.025687879647028948),
#     'taken': -1},
#    {'mean': np.float64(0.06830680330642773),
#     'median': np.float64(0.0347697888022789),
#     'taken': -1}],
#   'svcThreshold95': [{'mean': np.float64(0.03483437201861581),
#     'median': np.float64(-0.022901352454915952),
#     'taken': -1},
#    {'mean': np.float64(0.06349577701129133),
#     'median': np.float64(0.0182337097483905),
#     'taken': -1},
#    {'mean': np.float64(0.09088732460414957),
#     'median': np.float64(0.04393754530210485),
#     'taken': -1},
#    {'mean': np.float64(0.08563827553918574),
#     'median': np.float64(0.037243639231056044),
#     'taken': -1},
#    {'mean': np.float64(0.09696673198628096),
#     'median': np.float64(0.051816713256698704),
#     'taken': -1}]}}

# %%
# trainPipeline(cutoffs, yLabels, trainDf, testDf, thresholds, saveModel=True)
# Out:
# -----------------
# % of True in dataset 35.23% resulted in 33.35% and median 25.45%
# MODEL tree
# For alpha1Year, yCutoff = 0.1, taken used - 3602 is 34.12%
# Mean was 6.04%, median was 2.27%
# MODEL svc
# For alpha1Year, yCutoff = 0.1, taken used - 19 is 0.18%
# Mean was 5.73%, median was -1.89%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 7.47%, median was 1.82%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 7.62%, median was 3.64%
# -----------------
# -----------------
# % of True in dataset 28.24% resulted in 38.53% and median 29.9%
# MODEL tree
# For alpha1Year, yCutoff = 0.15, taken used - 3114 is 29.5%
# Mean was 5.69%, median was 1.17%
# MODEL svc
# For alpha1Year, yCutoff = 0.15, taken used - 9 is 0.09%
# Mean was 9.79%, median was -13.9%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 8.49%, median was 2.68%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 8.01%, median was 4.09%
# -----------------
# -----------------
# % of True in dataset 22.51% resulted in 43.88% and median 34.47%
# MODEL tree
# For alpha1Year, yCutoff = 0.2, taken used - 2572 is 24.37%
# Mean was 5.25%, median was 1.4%
# MODEL svc
# For alpha1Year, yCutoff = 0.2, taken used - 3 is 0.03%
# Mean was 58.91%, median was 80.06%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 7.77%, median was 3.4%
# % of True taken with threshold 95 adjustment -  529
# For threshold data - mean was 9.29%, median was 4.94%
# -----------------
# -----------------
# % of True in dataset 32.51% resulted in 60.56% and median 37.46%
# MODEL tree
# For alpha2Year, yCutoff = 0.1, taken used - 3902 is 36.96%
# Mean was 10.97%, median was -1.88%
# MODEL svc
# For alpha2Year, yCutoff = 0.1, taken used - 116 is 1.0999999999999999%
# Mean was 54.86%, median was 8.23%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 23.29%, median was 0.98%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 31.68%, median was 2.95%
# -----------------
# -----------------
# % of True in dataset 28.72% resulted in 66.91% and median 42.86%
# MODEL tree
# For alpha2Year, yCutoff = 0.15, taken used - 3497 is 33.129999999999995%
# Mean was 8.35%, median was -1.53%
# MODEL svc
# For alpha2Year, yCutoff = 0.15, taken used - 8 is 0.08%
# Mean was 94.52%, median was 5.05%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 23.85%, median was 1.81%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 30.28%, median was 2.75%
# -----------------
# -----------------
# % of True in dataset 25.33% resulted in 73.53% and median 48.83%
# MODEL tree
# For alpha2Year, yCutoff = 0.2, taken used - 2960 is 28.04%
# Mean was 9.82%, median was -0.12%
# MODEL svc
# For alpha2Year, yCutoff = 0.2, taken used - 3 is 0.03%
# Mean was -28.9%, median was -27.54%
# % of True taken with threshold 90 adjustment -  1056
# For threshold data - mean was 20.93%, median was 0.52%
# % of True taken with threshold 95 adjustment -  528
# For threshold data - mean was 30.67%, median was 2.55%
# -----------------
# {'alpha1Year': {'tree': [{'mean': np.float64(0.06036016084213012),
#     'median': np.float64(0.02272711924272555),
#     'taken': np.int64(3602)},
#    {'mean': np.float64(0.056872310887688966),
#     'median': np.float64(0.01172876676442605),
#     'taken': np.int64(3114)},
#    {'mean': np.float64(0.052522327238327386),
#     'median': np.float64(0.01395581407404505),
#     'taken': np.int64(2572)}],
#   'svc': [{'mean': np.float64(0.05725471820444397),
#     'median': np.float64(-0.0189153230747683),
#     'taken': np.int64(19)},
#    {'mean': np.float64(0.09791089394438221),
#     'median': np.float64(-0.1389913260393867),
#     'taken': np.int64(9)},
#    {'mean': np.float64(0.5890923759435145),
#     'median': np.float64(0.8006267657160063),
#     'taken': np.int64(3)}],
#   'svcThreshold90': [{'mean': np.float64(0.0746767941267405),
#     'median': np.float64(0.0182337097483905),
#     'taken': -1},
#    {'mean': np.float64(0.0849160674624662),
#     'median': np.float64(0.0268083570377613),
#     'taken': -1},
#    {'mean': np.float64(0.07765923443584069),
#     'median': np.float64(0.03403000045106405),
#     'taken': -1}],
#   'svcThreshold95': [{'mean': np.float64(0.07619687184399337),
#     'median': np.float64(0.036379146129128154),
#     'taken': -1},
#    {'mean': np.float64(0.08014970868144249),
#     'median': np.float64(0.04092665292035225),
#     'taken': -1},
#    {'mean': np.float64(0.09290420482726967),
#     'median': np.float64(0.0493616065596465),
#     'taken': -1}]},
#  'alpha2Year': {'tree': [{'mean': np.float64(0.10974961397134847),
#     'median': np.float64(-0.01883704906900955),
#     'taken': np.int64(3902)},
#    {'mean': np.float64(0.0835111386437622),
#     'median': np.float64(-0.0152656252134646),
#     'taken': np.int64(3497)},
#    {'mean': np.float64(0.09818766075199777),
#     'median': np.float64(-0.00124823956798975),
#     'taken': np.int64(2960)}],
#   'svc': [{'mean': np.float64(0.5485707736202109),
#     'median': np.float64(0.0822972767605338),
#     'taken': np.int64(116)},
#    {'mean': np.float64(0.9452305479497299),
#     'median': np.float64(0.0504634990887177),
#     'taken': np.int64(8)},
#    {'mean': np.float64(-0.289048613571299),
#     'median': np.float64(-0.2753680225404654),
#     'taken': np.int64(3)}],
#   'svcThreshold90': [{'mean': np.float64(0.23290110236130093),
#     'median': np.float64(0.00979977519101465),
#     'taken': -1},
#    {'mean': np.float64(0.23848953279455035),
#     'median': np.float64(0.0181356778553971),
#     'taken': -1},
#    {'mean': np.float64(0.20931219636774567),
#     'median': np.float64(0.0052054964369826),
#     'taken': -1}],
#   'svcThreshold95': [{'mean': np.float64(0.3167529713776928),
#     'median': np.float64(0.0295159458094134),
#     'taken': -1},
#    {'mean': np.float64(0.30281333938872046),
#     'median': np.float64(0.02751253081123335),
#     'taken': -1},
#    {'mean': np.float64(0.3066788566731633),
#     'median': np.float64(0.0254910926551208),
#     'taken': -1}]}}

# %%
noSpecReturns = []
diffs = []
for modelKey in modelKeys:
    for yLabel in yLabels:
        print('========')
        for cutoff in cutoffs:
            print(f'{modelKey} - {yLabel} - {cutoff}')
            grid = load(f'../data/cvPipeline-2/{modelKey}{yLabel}{cutoff}.joblib')
            y_pred = grid.predict(X_test)
            y_true = np.where(testDf[yLabel] <= cutoff, 0, 1)
            print(confusion_matrix(y_true, y_pred))
            print(classification_report(y_true, y_pred))
            xTaken = X_test[y_pred == 1]
            takenData = testDf.loc[testDf.index.intersection(xTaken.index)]
            print(f'Overall mean was {round(takenData.loc[:, yLabel].mean() * 100,2)}%')

            if modelKey != 'svc':
                continue
            model = grid.best_estimator_['svc']
            scaler = grid.best_estimator_['scaler']
            X_scaled = scaler.transform(X_test)
            scores = model.decision_function(X_scaled)
            for threshold in thresholds:
                barrier = np.percentile(scores, threshold)
                y_pred_threshold = scores >= barrier
                xTakenThreshold = X_test[y_pred_threshold]
                takenDataThreshold = testDf.loc[testDf.index.intersection(xTakenThreshold.index)]
                print(
                    f'For threshold {threshold} data - mean was {round(takenDataThreshold.loc[:, yLabel].mean() * 100, 2)}%')
                thresholdLabel = f'svcThreshold{threshold}'
                print(confusion_matrix(y_true, y_pred_threshold))
                print(classification_report(y_true, y_pred_threshold))

                returns = takenDataThreshold[yLabel]
                bins = pd.cut(returns, bins=[-1.0, -0.6, -0.3, -0.1, 0.1, 0.3, 0.6, 1.0, 10])
                bin_counts = bins.value_counts().sort_index()
                bin_df = bin_counts.reset_index()
                bin_df.columns = ['Bin Range', 'Count']
                print(bin_df)
                noSpecialReturns = mean(returns[returns < 1.0])
                noSpecReturns.append(noSpecialReturns)
                print(f'Without 100+% returns mean was {noSpecialReturns}.')
                diff = mean(returns) - noSpecialReturns
                diffs.append(diff)
                print(f'Generated diff = {diff}')
                print('--------')
# Out:
# ========
# svc - alpha1Year - 0.1
# [[6824   13]
#  [3713    6]]
#               precision    recall  f1-score   support
#
#            0       0.65      1.00      0.79      6837
#            1       0.32      0.00      0.00      3719
#
#     accuracy                           0.65     10556
#    macro avg       0.48      0.50      0.39     10556
# weighted avg       0.53      0.65      0.51     10556
#
# Overall mean was 5.73%
# For threshold 90 data - mean was 7.47%
# [[6191  646]
#  [3309  410]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.91      0.76      6837
#            1       0.39      0.11      0.17      3719
#
#     accuracy                           0.63     10556
#    macro avg       0.52      0.51      0.46     10556
# weighted avg       0.56      0.63      0.55     10556
#
#       Bin Range  Count
# 0  (-1.0, -0.6]      5
# 1  (-0.6, -0.3]     93
# 2  (-0.3, -0.1]    253
# 3   (-0.1, 0.1]    295
# 4    (0.1, 0.3]    211
# 5    (0.3, 0.6]    140
# 6    (0.6, 1.0]     39
# 7   (1.0, 10.0]     20
# Without 100+% returns mean was 0.036284297268616164.
# Generated diff = 0.038392496858124334
# --------
# For threshold 95 data - mean was 7.62%
# [[6530  307]
#  [3498  221]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.96      0.77      6837
#            1       0.42      0.06      0.10      3719
#
#     accuracy                           0.64     10556
#    macro avg       0.53      0.51      0.44     10556
# weighted avg       0.57      0.64      0.54     10556
#
#       Bin Range  Count
# 0  (-1.0, -0.6]      4
# 1  (-0.6, -0.3]     53
# 2  (-0.3, -0.1]    113
# 3   (-0.1, 0.1]    137
# 4    (0.1, 0.3]    113
# 5    (0.3, 0.6]     81
# 6    (0.6, 1.0]     18
# 7   (1.0, 10.0]      9
# Without 100+% returns mean was 0.04170092790550652.
# Generated diff = 0.03449594393848685
# --------
# svc - alpha1Year - 0.15
# [[7569    6]
#  [2978    3]]
#               precision    recall  f1-score   support
#
#            0       0.72      1.00      0.84      7575
#            1       0.33      0.00      0.00      2981
#
#     accuracy                           0.72     10556
#    macro avg       0.53      0.50      0.42     10556
# weighted avg       0.61      0.72      0.60     10556
#
# Overall mean was 9.79%
# For threshold 90 data - mean was 8.49%
# [[6873  702]
#  [2627  354]]
#               precision    recall  f1-score   support
#
#            0       0.72      0.91      0.81      7575
#            1       0.34      0.12      0.18      2981
#
#     accuracy                           0.68     10556
#    macro avg       0.53      0.51      0.49     10556
# weighted avg       0.61      0.68      0.63     10556
#
#       Bin Range  Count
# 0  (-1.0, -0.6]      4
# 1  (-0.6, -0.3]     88
# 2  (-0.3, -0.1]    242
# 3   (-0.1, 0.1]    297
# 4    (0.1, 0.3]    209
# 5    (0.3, 0.6]    152
# 6    (0.6, 1.0]     43
# 7   (1.0, 10.0]     21
# Without 100+% returns mean was 0.04834032455134503.
# Generated diff = 0.03657574291112117
# --------
# For threshold 95 data - mean was 8.01%
# [[7236  339]
#  [2792  189]]
#               precision    recall  f1-score   support
#
#            0       0.72      0.96      0.82      7575
#            1       0.36      0.06      0.11      2981
#
#     accuracy                           0.70     10556
#    macro avg       0.54      0.51      0.46     10556
# weighted avg       0.62      0.70      0.62     10556
#
#       Bin Range  Count
# 0  (-1.0, -0.6]      4
# 1  (-0.6, -0.3]     47
# 2  (-0.3, -0.1]    114
# 3   (-0.1, 0.1]    139
# 4    (0.1, 0.3]    112
# 5    (0.3, 0.6]     80
# 6    (0.6, 1.0]     22
# 7   (1.0, 10.0]     10
# Without 100+% returns mean was 0.05040362004789564.
# Generated diff = 0.029746088633546844
# --------
# svc - alpha1Year - 0.2
# [[8179    1]
#  [2374    2]]
#               precision    recall  f1-score   support
#
#            0       0.78      1.00      0.87      8180
#            1       0.67      0.00      0.00      2376
#
#     accuracy                           0.78     10556
#    macro avg       0.72      0.50      0.44     10556
# weighted avg       0.75      0.78      0.68     10556
#
# Overall mean was 58.91%
# For threshold 90 data - mean was 7.77%
# [[7426  754]
#  [2074  302]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.91      0.84      8180
#            1       0.29      0.13      0.18      2376
#
#     accuracy                           0.73     10556
#    macro avg       0.53      0.52      0.51     10556
# weighted avg       0.67      0.73      0.69     10556
#
#       Bin Range  Count
# 0  (-1.0, -0.6]      4
# 1  (-0.6, -0.3]     94
# 2  (-0.3, -0.1]    230
# 3   (-0.1, 0.1]    300
# 4    (0.1, 0.3]    217
# 5    (0.3, 0.6]    158
# 6    (0.6, 1.0]     36
# 7   (1.0, 10.0]     17
# Without 100+% returns mean was 0.04850954864773221.
# Generated diff = 0.029149685788108483
# --------
# For threshold 95 data - mean was 9.29%
# [[7810  370]
#  [2217  159]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.95      0.86      8180
#            1       0.30      0.07      0.11      2376
#
#     accuracy                           0.75     10556
#    macro avg       0.54      0.51      0.48     10556
# weighted avg       0.67      0.75      0.69     10556
#
#       Bin Range  Count
# 0  (-1.0, -0.6]      1
# 1  (-0.6, -0.3]     43
# 2  (-0.3, -0.1]    110
# 3   (-0.1, 0.1]    147
# 4    (0.1, 0.3]    118
# 5    (0.3, 0.6]     78
# 6    (0.6, 1.0]     20
# 7   (1.0, 10.0]     12
# Without 100+% returns mean was 0.05780688158218885.
# Generated diff = 0.03509732324508082
# --------
# ========
# svc - alpha2Year - 0.1
# [[7064   60]
#  [3376   56]]
#               precision    recall  f1-score   support
#
#            0       0.68      0.99      0.80      7124
#            1       0.48      0.02      0.03      3432
#
#     accuracy                           0.67     10556
#    macro avg       0.58      0.50      0.42     10556
# weighted avg       0.61      0.67      0.55     10556
#
# Overall mean was 54.86%
# For threshold 90 data - mean was 23.29%
# [[6518  606]
#  [2982  450]]
#               precision    recall  f1-score   support
#
#            0       0.69      0.91      0.78      7124
#            1       0.43      0.13      0.20      3432
#
#     accuracy                           0.66     10556
#    macro avg       0.56      0.52      0.49     10556
# weighted avg       0.60      0.66      0.59     10556
#
#       Bin Range  Count
# 0  (-1.0, -0.6]     58
# 1  (-0.6, -0.3]    180
# 2  (-0.3, -0.1]    188
# 3   (-0.1, 0.1]    173
# 4    (0.1, 0.3]    130
# 5    (0.3, 0.6]    160
# 6    (0.6, 1.0]     84
# 7   (1.0, 10.0]     71
# Without 100+% returns mean was -0.008919166966698295.
# Generated diff = 0.24182026932799922
# --------
# For threshold 95 data - mean was 31.68%
# [[6836  288]
#  [3192  240]]
#               precision    recall  f1-score   support
#
#            0       0.68      0.96      0.80      7124
#            1       0.45      0.07      0.12      3432
#
#     accuracy                           0.67     10556
#    macro avg       0.57      0.51      0.46     10556
# weighted avg       0.61      0.67      0.58     10556
#
#       Bin Range  Count
# 0  (-1.0, -0.6]     33
# 1  (-0.6, -0.3]     87
# 2  (-0.3, -0.1]     88
# 3   (-0.1, 0.1]     76
# 4    (0.1, 0.3]     71
# 5    (0.3, 0.6]     74
# 6    (0.6, 1.0]     46
# 7   (1.0, 10.0]     46
# Without 100+% returns mean was -0.004935389474375405.
# Generated diff = 0.3216883608520682
# --------
# svc - alpha2Year - 0.15
# [[7519    5]
#  [3029    3]]
#               precision    recall  f1-score   support
#
#            0       0.71      1.00      0.83      7524
#            1       0.38      0.00      0.00      3032
#
#     accuracy                           0.71     10556
#    macro avg       0.54      0.50      0.42     10556
# weighted avg       0.62      0.71      0.59     10556
#
# Overall mean was 94.52%
# For threshold 90 data - mean was 23.85%
# [[6897  627]
#  [2603  429]]
#               precision    recall  f1-score   support
#
#            0       0.73      0.92      0.81      7524
#            1       0.41      0.14      0.21      3032
#
#     accuracy                           0.69     10556
#    macro avg       0.57      0.53      0.51     10556
# weighted avg       0.63      0.69      0.64     10556
#
#       Bin Range  Count
# 0  (-1.0, -0.6]     62
# 1  (-0.6, -0.3]    184
# 2  (-0.3, -0.1]    183
# 3   (-0.1, 0.1]    161
# 4    (0.1, 0.3]    128
# 5    (0.3, 0.6]    159
# 6    (0.6, 1.0]     90
# 7   (1.0, 10.0]     76
# Without 100+% returns mean was -0.008455179842489552.
# Generated diff = 0.2469447126370399
# --------
# For threshold 95 data - mean was 30.28%
# [[7218  306]
#  [2810  222]]
#               precision    recall  f1-score   support
#
#            0       0.72      0.96      0.82      7524
#            1       0.42      0.07      0.12      3032
#
#     accuracy                           0.70     10556
#    macro avg       0.57      0.52      0.47     10556
# weighted avg       0.63      0.70      0.62     10556
#
#       Bin Range  Count
# 0  (-1.0, -0.6]     36
# 1  (-0.6, -0.3]     86
# 2  (-0.3, -0.1]     96
# 3   (-0.1, 0.1]     69
# 4    (0.1, 0.3]     69
# 5    (0.3, 0.6]     72
# 6    (0.6, 1.0]     48
# 7   (1.0, 10.0]     46
# Without 100+% returns mean was -0.010050980281286058.
# Generated diff = 0.3128643196700065
# --------
# svc - alpha2Year - 0.2
# [[7879    3]
#  [2674    0]]
#               precision    recall  f1-score   support
#
#            0       0.75      1.00      0.85      7882
#            1       0.00      0.00      0.00      2674
#
#     accuracy                           0.75     10556
#    macro avg       0.37      0.50      0.43     10556
# weighted avg       0.56      0.75      0.64     10556
#
# Overall mean was -28.9%
# For threshold 90 data - mean was 20.93%
# [[7224  658]
#  [2276  398]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.92      0.83      7882
#            1       0.38      0.15      0.21      2674
#
#     accuracy                           0.72     10556
#    macro avg       0.57      0.53      0.52     10556
# weighted avg       0.66      0.72      0.67     10556
#
#       Bin Range  Count
# 0  (-1.0, -0.6]     66
# 1  (-0.6, -0.3]    197
# 2  (-0.3, -0.1]    184
# 3   (-0.1, 0.1]    147
# 4    (0.1, 0.3]    118
# 5    (0.3, 0.6]    155
# 6    (0.6, 1.0]     93
# 7   (1.0, 10.0]     84
# Without 100+% returns mean was -0.020652455828868866.
# Generated diff = 0.22996465219661455
# --------
# For threshold 95 data - mean was 30.67%
# [[7561  321]
#  [2467  207]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.96      0.84      7882
#            1       0.39      0.08      0.13      2674
#
#     accuracy                           0.74     10556
#    macro avg       0.57      0.52      0.49     10556
# weighted avg       0.66      0.74      0.66     10556
#
#       Bin Range  Count
# 0  (-1.0, -0.6]     37
# 1  (-0.6, -0.3]     83
# 2  (-0.3, -0.1]    101
# 3   (-0.1, 0.1]     68
# 4    (0.1, 0.3]     65
# 5    (0.3, 0.6]     72
# 6    (0.6, 1.0]     50
# 7   (1.0, 10.0]     46
# Without 100+% returns mean was -0.010077160042691458.
# Generated diff = 0.31675601671585474
# --------
# ========
# tree - alpha1Year - 0.1
# [[4613 2224]
#  [2341 1378]]
#               precision    recall  f1-score   support
#
#            0       0.66      0.67      0.67      6837
#            1       0.38      0.37      0.38      3719
#
#     accuracy                           0.57     10556
#    macro avg       0.52      0.52      0.52     10556
# weighted avg       0.56      0.57      0.57     10556
#
# Overall mean was 6.04%
# tree - alpha1Year - 0.15
# [[5415 2160]
#  [2027  954]]
#               precision    recall  f1-score   support
#
#            0       0.73      0.71      0.72      7575
#            1       0.31      0.32      0.31      2981
#
#     accuracy                           0.60     10556
#    macro avg       0.52      0.52      0.52     10556
# weighted avg       0.61      0.60      0.61     10556
#
# Overall mean was 5.69%
# tree - alpha1Year - 0.2
# [[6268 1912]
#  [1716  660]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.77      0.78      8180
#            1       0.26      0.28      0.27      2376
#
#     accuracy                           0.66     10556
#    macro avg       0.52      0.52      0.52     10556
# weighted avg       0.67      0.66      0.66     10556
#
# Overall mean was 5.25%
# ========
# tree - alpha2Year - 0.1
# [[4726 2398]
#  [1928 1504]]
#               precision    recall  f1-score   support
#
#            0       0.71      0.66      0.69      7124
#            1       0.39      0.44      0.41      3432
#
#     accuracy                           0.59     10556
#    macro avg       0.55      0.55      0.55     10556
# weighted avg       0.60      0.59      0.60     10556
#
# Overall mean was 10.97%
# tree - alpha2Year - 0.15
# [[5256 2268]
#  [1803 1229]]
#               precision    recall  f1-score   support
#
#            0       0.74      0.70      0.72      7524
#            1       0.35      0.41      0.38      3032
#
#     accuracy                           0.61     10556
#    macro avg       0.55      0.55      0.55     10556
# weighted avg       0.63      0.61      0.62     10556
#
# Overall mean was 8.35%
# tree - alpha2Year - 0.2
# [[5897 1985]
#  [1699  975]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.75      0.76      7882
#            1       0.33      0.36      0.35      2674
#
#     accuracy                           0.65     10556
#    macro avg       0.55      0.56      0.55     10556
# weighted avg       0.66      0.65      0.66     10556
#
# Overall mean was 9.82%

# %%
print(mean(noSpecReturns))
print(mean(diffs))
# Out:
# 0.018329605630572895
# 0.1561246343978376

# %% [markdown]
# Kompletne zniszczenie 2y returns

# %%
print(diffs)
# Out:
# [np.float64(0.038392496858124334), np.float64(0.03449594393848685), np.float64(0.03657574291112117), np.float64(0.029746088633546844), np.float64(0.029149685788108483), np.float64(0.03509732324508082), np.float64(0.24182026932799922), np.float64(0.3216883608520682), np.float64(0.2469447126370399), np.float64(0.3128643196700065), np.float64(0.22996465219661455), np.float64(0.31675601671585474)]

# %% [markdown]
# TO SAMO TYLKO DLA BALANCED

# %%
noSpecReturns = []
diffs = []
for modelKey in modelKeys:
    for yLabel in yLabels:
        print('========')
        for cutoff in cutoffs:
            print(f'{modelKey} - {yLabel} - {cutoff}')
            grid = load(f'../data/cvPipeline-2/balanced/{modelKey}{yLabel}{cutoff}.joblib')
            y_pred = grid.predict(X_test)
            y_true = np.where(testDf[yLabel] <= cutoff, 0, 1)
            print(confusion_matrix(y_true, y_pred))
            print(classification_report(y_true, y_pred))
            xTaken = X_test[y_pred == 1]
            takenData = testDf.loc[testDf.index.intersection(xTaken.index)]
            print(f'Overall mean was {round(takenData.loc[:, yLabel].mean() * 100,2)}%')
            returns = takenData[yLabel]
            bins = pd.cut(returns, bins=[-1.0, -0.6, -0.3, -0.1, 0.1, 0.3, 0.6, 1.0, 10])
            bin_counts = bins.value_counts().sort_index()
            bin_df = bin_counts.reset_index()
            bin_df.columns = ['Bin Range', 'Count']
            print(bin_df)

            if modelKey != 'svc':
                continue
            model = grid.best_estimator_['svc']
            scaler = grid.best_estimator_['scaler']
            X_scaled = scaler.transform(X_test)
            scores = model.decision_function(X_scaled)
            for threshold in thresholds:
                barrier = np.percentile(scores, threshold)
                y_pred_threshold = scores >= barrier
                xTakenThreshold = X_test[y_pred_threshold]
                takenDataThreshold = testDf.loc[testDf.index.intersection(xTakenThreshold.index)]
                print(
                    f'For threshold {threshold} data - mean was {round(takenDataThreshold.loc[:, yLabel].mean() * 100, 2)}%')
                thresholdLabel = f'svcThreshold{threshold}'
                print(confusion_matrix(y_true, y_pred_threshold))
                print(classification_report(y_true, y_pred_threshold))

                returns = takenDataThreshold[yLabel]
                bins = pd.cut(returns, bins=[-1.0, -0.6, -0.3, -0.1, 0.1, 0.3, 0.6, 1.0, 10])
                bin_counts = bins.value_counts().sort_index()
                bin_df = bin_counts.reset_index()
                bin_df.columns = ['Bin Range', 'Count']
                print(bin_df)
                noSpecialReturns = mean(returns[returns < 1.0])
                noSpecReturns.append(noSpecialReturns)
                print(f'Without 100+% returns mean was {noSpecialReturns}.')
                diff = mean(returns) - noSpecialReturns
                diffs.append(diff)
                print(f'Generated diff = {diff}')
                print('--------')
# Out:
# ========
# svc - alpha1Year - 0.0
# [[2864 2317]
#  [2882 2493]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.55      0.52      5181
#            1       0.52      0.46      0.49      5375
#
#     accuracy                           0.51     10556
#    macro avg       0.51      0.51      0.51     10556
# weighted avg       0.51      0.51      0.51     10556
#
# Overall mean was 4.8%
#       Bin Range  Count
# 0  (-1.0, -0.6]     27
# 1  (-0.6, -0.3]    390
# 2  (-0.3, -0.1]   1156
# 3   (-0.1, 0.1]   1506
# 4    (0.1, 0.3]    987
# 5    (0.3, 0.6]    549
# 6    (0.6, 1.0]    134
# 7   (1.0, 10.0]     61
# For threshold 90 data - mean was 7.81%
# [[4673  508]
#  [4827  548]]
#               precision    recall  f1-score   support
#
#            0       0.49      0.90      0.64      5181
#            1       0.52      0.10      0.17      5375
#
#     accuracy                           0.49     10556
#    macro avg       0.51      0.50      0.40     10556
# weighted avg       0.51      0.49      0.40     10556
#
#       Bin Range  Count
# 0  (-1.0, -0.6]      5
# 1  (-0.6, -0.3]     88
# 2  (-0.3, -0.1]    257
# 3   (-0.1, 0.1]    303
# 4    (0.1, 0.3]    202
# 5    (0.3, 0.6]    140
# 6    (0.6, 1.0]     40
# 7   (1.0, 10.0]     21
# Without 100+% returns mean was 0.034822059164173726.
# Generated diff = 0.04329498667651777
# --------
# For threshold 95 data - mean was 3.48%
# [[4903  278]
#  [5125  250]]
#               precision    recall  f1-score   support
#
#            0       0.49      0.95      0.64      5181
#            1       0.47      0.05      0.08      5375
#
#     accuracy                           0.49     10556
#    macro avg       0.48      0.50      0.36     10556
# weighted avg       0.48      0.49      0.36     10556
#
#       Bin Range  Count
# 0  (-1.0, -0.6]      4
# 1  (-0.6, -0.3]     58
# 2  (-0.3, -0.1]    139
# 3   (-0.1, 0.1]    135
# 4    (0.1, 0.3]     94
# 5    (0.3, 0.6]     70
# 6    (0.6, 1.0]     20
# 7   (1.0, 10.0]      8
# Without 100+% returns mean was 0.01351785687481928.
# Generated diff = 0.02131651514379653
# --------
# svc - alpha1Year - 0.1
# [[3676 3161]
#  [1892 1827]]
#               precision    recall  f1-score   support
#
#            0       0.66      0.54      0.59      6837
#            1       0.37      0.49      0.42      3719
#
#     accuracy                           0.52     10556
#    macro avg       0.51      0.51      0.51     10556
# weighted avg       0.56      0.52      0.53     10556
#
# Overall mean was 4.75%
#       Bin Range  Count
# 0  (-1.0, -0.6]     29
# 1  (-0.6, -0.3]    434
# 2  (-0.3, -0.1]   1172
# 3   (-0.1, 0.1]   1526
# 4    (0.1, 0.3]   1041
# 5    (0.3, 0.6]    582
# 6    (0.6, 1.0]    148
# 7   (1.0, 10.0]     56
# For threshold 90 data - mean was 7.15%
# [[6179  658]
#  [3321  398]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.90      0.76      6837
#            1       0.38      0.11      0.17      3719
#
#     accuracy                           0.62     10556
#    macro avg       0.51      0.51      0.46     10556
# weighted avg       0.55      0.62      0.55     10556
#
#       Bin Range  Count
# 0  (-1.0, -0.6]      5
# 1  (-0.6, -0.3]     95
# 2  (-0.3, -0.1]    252
# 3   (-0.1, 0.1]    306
# 4    (0.1, 0.3]    201
# 5    (0.3, 0.6]    137
# 6    (0.6, 1.0]     39
# 7   (1.0, 10.0]     21
# Without 100+% returns mean was 0.03208398509560814.
# Generated diff = 0.03944253669464812
# --------
# For threshold 95 data - mean was 6.35%
# [[6518  319]
#  [3510  209]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.95      0.77      6837
#            1       0.40      0.06      0.10      3719
#
#     accuracy                           0.64     10556
#    macro avg       0.52      0.50      0.44     10556
# weighted avg       0.56      0.64      0.54     10556
#
#       Bin Range  Count
# 0  (-1.0, -0.6]      4
# 1  (-0.6, -0.3]     55
# 2  (-0.3, -0.1]    126
# 3   (-0.1, 0.1]    134
# 4    (0.1, 0.3]    103
# 5    (0.3, 0.6]     79
# 6    (0.6, 1.0]     18
# 7   (1.0, 10.0]      9
# Without 100+% returns mean was 0.02877958287339346.
# Generated diff = 0.03471619413789787
# --------
# svc - alpha1Year - 0.15
# [[4122 3453]
#  [1471 1510]]
#               precision    recall  f1-score   support
#
#            0       0.74      0.54      0.63      7575
#            1       0.30      0.51      0.38      2981
#
#     accuracy                           0.53     10556
#    macro avg       0.52      0.53      0.50     10556
# weighted avg       0.61      0.53      0.56     10556
#
# Overall mean was 4.92%
#       Bin Range  Count
# 0  (-1.0, -0.6]     27
# 1  (-0.6, -0.3]    422
# 2  (-0.3, -0.1]   1160
# 3   (-0.1, 0.1]   1509
# 4    (0.1, 0.3]   1061
# 5    (0.3, 0.6]    580
# 6    (0.6, 1.0]    151
# 7   (1.0, 10.0]     53
# For threshold 90 data - mean was 7.64%
# [[6870  705]
#  [2630  351]]
#               precision    recall  f1-score   support
#
#            0       0.72      0.91      0.80      7575
#            1       0.33      0.12      0.17      2981
#
#     accuracy                           0.68     10556
#    macro avg       0.53      0.51      0.49     10556
# weighted avg       0.61      0.68      0.63     10556
#
#       Bin Range  Count
# 0  (-1.0, -0.6]      5
# 1  (-0.6, -0.3]     89
# 2  (-0.3, -0.1]    245
# 3   (-0.1, 0.1]    301
# 4    (0.1, 0.3]    207
# 5    (0.3, 0.6]    150
# 6    (0.6, 1.0]     39
# 7   (1.0, 10.0]     20
# Without 100+% returns mean was 0.0438068513908197.
# Generated diff = 0.03260252819908834
# --------
# For threshold 95 data - mean was 9.09%
# [[7238  337]
#  [2790  191]]
#               precision    recall  f1-score   support
#
#            0       0.72      0.96      0.82      7575
#            1       0.36      0.06      0.11      2981
#
#     accuracy                           0.70     10556
#    macro avg       0.54      0.51      0.47     10556
# weighted avg       0.62      0.70      0.62     10556
#
#       Bin Range  Count
# 0  (-1.0, -0.6]      4
# 1  (-0.6, -0.3]     48
# 2  (-0.3, -0.1]    111
# 3   (-0.1, 0.1]    139
# 4    (0.1, 0.3]    113
# 5    (0.3, 0.6]     78
# 6    (0.6, 1.0]     22
# 7   (1.0, 10.0]     13
# Without 100+% returns mean was 0.0512570170062524.
# Generated diff = 0.039630307597897166
# --------
# svc - alpha1Year - 0.2
# [[4542 3638]
#  [1133 1243]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.56      0.66      8180
#            1       0.25      0.52      0.34      2376
#
#     accuracy                           0.55     10556
#    macro avg       0.53      0.54      0.50     10556
# weighted avg       0.68      0.55      0.59     10556
#
# Overall mean was 5.05%
#       Bin Range  Count
# 0  (-1.0, -0.6]     26
# 1  (-0.6, -0.3]    410
# 2  (-0.3, -0.1]   1123
# 3   (-0.1, 0.1]   1499
# 4    (0.1, 0.3]   1044
# 5    (0.3, 0.6]    581
# 6    (0.6, 1.0]    149
# 7   (1.0, 10.0]     49
# For threshold 90 data - mean was 7.29%
# [[7423  757]
#  [2077  299]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.91      0.84      8180
#            1       0.28      0.13      0.17      2376
#
#     accuracy                           0.73     10556
#    macro avg       0.53      0.52      0.51     10556
# weighted avg       0.67      0.73      0.69     10556
#
#       Bin Range  Count
# 0  (-1.0, -0.6]      8
# 1  (-0.6, -0.3]     93
# 2  (-0.3, -0.1]    234
# 3   (-0.1, 0.1]    304
# 4    (0.1, 0.3]    208
# 5    (0.3, 0.6]    153
# 6    (0.6, 1.0]     38
# 7   (1.0, 10.0]     18
# Without 100+% returns mean was 0.04352677412929043.
# Generated diff = 0.02937785272434912
# --------
# For threshold 95 data - mean was 8.56%
# [[7805  375]
#  [2223  153]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.95      0.86      8180
#            1       0.29      0.06      0.11      2376
#
#     accuracy                           0.75     10556
#    macro avg       0.53      0.51      0.48     10556
# weighted avg       0.67      0.75      0.69     10556
#
#       Bin Range  Count
# 0  (-1.0, -0.6]      3
# 1  (-0.6, -0.3]     45
# 2  (-0.3, -0.1]    109
# 3   (-0.1, 0.1]    154
# 4    (0.1, 0.3]    111
# 5    (0.3, 0.6]     73
# 6    (0.6, 1.0]     20
# 7   (1.0, 10.0]     13
# Without 100+% returns mean was 0.04627534554582535.
# Generated diff = 0.039362929993360385
# --------
# svc - alpha1Year - 0.35
# [[5310 4091]
#  [ 561  594]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.56      0.70      9401
#            1       0.13      0.51      0.20      1155
#
#     accuracy                           0.56     10556
#    macro avg       0.52      0.54      0.45     10556
# weighted avg       0.82      0.56      0.64     10556
#
# Overall mean was 5.14%
#       Bin Range  Count
# 0  (-1.0, -0.6]     25
# 1  (-0.6, -0.3]    394
# 2  (-0.3, -0.1]   1069
# 3   (-0.1, 0.1]   1428
# 4    (0.1, 0.3]   1010
# 5    (0.3, 0.6]    566
# 6    (0.6, 1.0]    148
# 7   (1.0, 10.0]     45
# For threshold 90 data - mean was 6.83%
# [[8497  904]
#  [1003  152]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.90      0.90      9401
#            1       0.14      0.13      0.14      1155
#
#     accuracy                           0.82     10556
#    macro avg       0.52      0.52      0.52     10556
# weighted avg       0.81      0.82      0.82     10556
#
#       Bin Range  Count
# 0  (-1.0, -0.6]      9
# 1  (-0.6, -0.3]     98
# 2  (-0.3, -0.1]    211
# 3   (-0.1, 0.1]    315
# 4    (0.1, 0.3]    228
# 5    (0.3, 0.6]    141
# 6    (0.6, 1.0]     37
# 7   (1.0, 10.0]     17
# Without 100+% returns mean was 0.04350618014197726.
# Generated diff = 0.024800623164450468
# --------
# For threshold 95 data - mean was 9.7%
# [[8958  443]
#  [1070   85]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92      9401
#            1       0.16      0.07      0.10      1155
#
#     accuracy                           0.86     10556
#    macro avg       0.53      0.51      0.51     10556
# weighted avg       0.81      0.86      0.83     10556
#
#       Bin Range  Count
# 0  (-1.0, -0.6]      3
# 1  (-0.6, -0.3]     43
# 2  (-0.3, -0.1]    107
# 3   (-0.1, 0.1]    140
# 4    (0.1, 0.3]    127
# 5    (0.3, 0.6]     75
# 6    (0.6, 1.0]     20
# 7   (1.0, 10.0]     13
# Without 100+% returns mean was 0.059474523291221965.
# Generated diff = 0.037492208695058996
# --------

# %%
3 + 43 + 107 + 140 + 127 + 75 + 20 + 13
# Out:
# 528

# %%
443+85
# Out:
# 528
