# %%
from analysis.training_helper import trainPipeline
from utils.custom_train_test_split import per_year_train_test_split
import matplotlib.pyplot as plt

files = ['../../data/deduplicated/combined_inner_ticker.csv']
cutoffs = [0.0, 0.01, 0.02, 0.03, 0.05, 0.07, 0.10, 0.15, 0.20, 0.25, 0.35]
thresholds = [70, 80, 90, 95]


trainDf, testDf = per_year_train_test_split(files, format='%Y-%m-%d')
resultsToPlotYear = trainPipeline(cutoffs, ['alpha1Year'], trainDf, testDf, thresholds)


plt.plot(cutoffs, resultsToPlotYear['alpha1Year'], marker='o', linestyle='-', color='r', label='Data')

plt.xlabel('cutoff')
plt.ylabel('% of ones')
plt.title('Cutoff influence on % of ones in dataset')
plt.ylim(0, 60)
plt.grid(True)
plt.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 10
#       6 cutoffs = [0.0, 0.01, 0.02, 0.03, 0.05, 0.07, 0.10, 0.15, 0.20, 0.25, 0.35]
#       7 thresholds = [70, 80, 90, 95]
# ---> 10 trainDf, testDf = per_year_train_test_split(files, format='%Y-%m-%d')
#      11 resultsToPlotYear = trainPipeline(cutoffs, ['alpha1Year'], trainDf, testDf, thresholds)
#      14 plt.plot(cutoffs, resultsToPlotYear['alpha1Year'], marker='o', linestyle='-', color='r', label='Data')
#
# File F:\programowanie\studia\magisterka\sec_scrapper2\finchat\utils\custom_train_test_split.py:18, in per_year_train_test_split(paths, splitDate, format)
#      16 splitDate = pd.to_datetime(splitDate, format='%d-%m-%Y')
#      17 df = joinDfs(paths)
# ---> 18 df['date'] = df['date'].apply(lambda x: pd.to_datetime(x, format=format))
#      19 trainData = df[df['date'] <= splitDate]
# ...
